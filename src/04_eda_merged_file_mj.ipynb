# %%
library("ggplot2")

# %%
titles = read.delim('./../dataset/merge_basics_ratings_crew.tsv',header=TRUE)

# %%
head(titles)
# Out:
#   tconst    titleType isAdult startYear runtimeMinutes genre1      genre2
# 1 tt0000001 short     0       1894       1             Documentary Short
# 2 tt0000002 short     0       1892       5             Animation   Short
# 3 tt0000003 short     0       1892       4             Animation   Comedy
# 4 tt0000004 short     0       1892      12             Animation   Short
# 5 tt0000005 short     0       1893       1             Comedy      Short
# 6 tt0000006 short     0       1894       1             Short       0
#   genre3  averageRating numVotes n_directors n_writers
# 1 0       5.6           1654     1           1
# 2 0       6.1            199     1           1
# 3 Romance 6.5           1366     1           1
# 4 0       6.2            121     1           1
# 5 0       6.2           2149     1           1
# 6 0       5.3            115     1           1

# %%
titles$isAdult = as.factor(titles$isAdult)

# %%
## short
ggplot(titles, aes(x=titleType)) + 
    geom_bar()
# Out:
# plot without title

# %%
## isAdult
ggplot(titles, aes(x=isAdult)) + 
    geom_bar()
# Out:
# plot without title

# %%
## startYear
ggplot(titles, aes(x=startYear)) + 
    geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(titles, aes(x=genre1, y=startYear)) + 
    geom_violin()
# Out:
# plot without title

# %%
## runtimeMinutes
ggplot(titles, aes(x=runtimeMinutes)) + 
    geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
