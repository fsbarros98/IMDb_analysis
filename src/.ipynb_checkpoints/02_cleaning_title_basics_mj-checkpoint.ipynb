# %% [markdown]
# # Title Basics

# %%
library("ggplot2")

# %%
title_basics = read.delim("./../dataset/filtered.title.basics.tsv",header=TRUE)

# %%
nrow(title_basics)
# Out:
# [1] 1443759

# %%
head(title_basics)
# Out:
#   tconst    titleType primaryTitle           originalTitle          isAdult
# 1 tt0000001 short     Carmencita             Carmencita             0
# 2 tt0000002 short     Le clown et ses chiens Le clown et ses chiens 0
# 3 tt0000003 short     Pauvre Pierrot         Pauvre Pierrot         0
# 4 tt0000004 short     Un bon bock            Un bon bock            0
# 5 tt0000005 short     Blacksmith Scene       Blacksmith Scene       0
# 6 tt0000006 short     Chinese Opium Den      Chinese Opium Den      0
#   startYear endYear runtimeMinutes genres
# 1 1894      \\N     1              Documentary,Short
# 2 1892      \\N     5              Animation,Short
# 3 1892      \\N     4              Animation,Comedy,Romance
# 4 1892      \\N     12             Animation,Short
# 5 1893      \\N     1              Comedy,Short
# 6 1894      \\N     1              Short

# %%
tail(title_basics)
# Out:
#         tconst    titleType primaryTitle
# 1443754 tt9916724 short     Hay Que Ser Paciente
# 1443755 tt9916730 movie     6 Gunn
# 1443756 tt9916754 movie     Chico Albuquerque - Revela̵̤es
# 1443757 tt9916756 short     Pretty Pretty Black Girl
# 1443758 tt9916764 short     38
# 1443759 tt9916856 short     The Wind
#         originalTitle                    isAdult startYear endYear
# 1443754 Hay Que Ser Paciente             0       2015      \\N
# 1443755 6 Gunn                           0       2017      \\N
# 1443756 Chico Albuquerque - Revela̵̤es 0       2013      \\N
# 1443757 Pretty Pretty Black Girl         0       2019      \\N
# 1443758 38                               0       2018      \\N
# 1443759 The Wind                         0       2015      \\N
#         runtimeMinutes genres
# 1443754 3              Documentary,Short
# 1443755 116            \\N
# 1443756 49             Documentary
# 1443757 \\N            Short
# 1443758 \\N            Short
# ...

# %%
# any change in title_aka will be done in ta_clean
tb_clean = title_basics

# %%
#tb_clean$runtimeMinutes = as.numeric(tb_clean$runtimeMinutes)

# %% [markdown]
# ### tconst

# %%
levels(tb_clean$tconst)
# Out:
#     [1] "tt0000001" "tt0000002" "tt0000003" "tt0000004" "tt0000005" "tt0000006"
#     [7] "tt0000007" "tt0000008" "tt0000009" "tt0000010" "tt0000011" "tt0000012"
#    [13] "tt0000013" "tt0000014" "tt0000015" "tt0000016" "tt0000017" "tt0000018"
#    [19] "tt0000019" "tt0000020" "tt0000022" "tt0000023" "tt0000024" "tt0000025"
#    [25] "tt0000026" "tt0000027" "tt0000028" "tt0000029" "tt0000030" "tt0000031"
#    [31] "tt0000032" "tt0000033" "tt0000034" "tt0000035" "tt0000036" "tt0000037"
#    [37] "tt0000038" "tt0000039" "tt0000040" "tt0000041" "tt0000042" "tt0000043"
#    [43] "tt0000044" "tt0000045" "tt0000046" "tt0000047" "tt0000048" "tt0000049"
#    [49] "tt0000050" "tt0000051" "tt0000052" "tt0000053" "tt0000054" "tt0000055"
#    [55] "tt0000056" "tt0000057" "tt0000058" "tt0000059" "tt0000060" "tt0000061"
#    [61] "tt0000062" "tt0000063" "tt0000064" "tt0000065" "tt0000066" "tt0000067"
#    [67] "tt0000068" "tt0000069" "tt0000070" "tt0000071" "tt0000072" "tt0000073"
# ...

# %% [markdown]
# ### title type

# %%
levels(tb_clean$titleType)
# Out:
# [1] "movie"   "short"   "tvMovie"

# %% [markdown]
# ### primaryTitle and originalTitle

# %% [markdown]
# levels(tb_clean$primaryTitle)

# %% [markdown]
# * both of these features don't add relevant and usable information (analyse of strings is very high computatinal cost)

# %%
tb_clean$primaryTitle = NULL
tb_clean$originalTitle = NULL

# %% [markdown]
# ### isAdult

# %%
tb_clean$isAdult = as.factor(tb_clean$isAdult)

# %%
levels(tb_clean$isAdult)
# Out:
# [1] "0" "1"

# %%
ggplot(tb_clean, aes(x=isAdult)) + geom_bar()
# Out:
# plot without title

# %%
nrow(tb_clean[tb_clean$isAdult==1,])/nrow(tb_clean)
nrow(tb_clean[tb_clean$isAdult==1,])
# Out:
# [1] 0.007147315
# [1] 10319

# %% [markdown]
# ### startYear

# %%
levels(tb_clean$startYear)
# Out:
#   [1] "\\N"  "1874" "1878" "1881" "1883" "1885" "1887" "1888" "1889" "1890"
#  [11] "1891" "1892" "1893" "1894" "1895" "1896" "1897" "1898" "1899" "1900"
#  [21] "1901" "1902" "1903" "1904" "1905" "1906" "1907" "1908" "1909" "1910"
#  [31] "1911" "1912" "1913" "1914" "1915" "1916" "1917" "1918" "1919" "1920"
#  [41] "1921" "1922" "1923" "1924" "1925" "1926" "1927" "1928" "1929" "1930"
#  [51] "1931" "1932" "1933" "1934" "1935" "1936" "1937" "1938" "1939" "1940"
#  [61] "1941" "1942" "1943" "1944" "1945" "1946" "1947" "1948" "1949" "1950"
#  [71] "1951" "1952" "1953" "1954" "1955" "1956" "1957" "1958" "1959" "1960"
#  [81] "1961" "1962" "1963" "1964" "1965" "1966" "1967" "1968" "1969" "1970"
#  [91] "1971" "1972" "1973" "1974" "1975" "1976" "1977" "1978" "1979" "1980"
# [101] "1981" "1982" "1983" "1984" "1985" "1986" "1987" "1988" "1989" "1990"
# [111] "1991" "1992" "1993" "1994" "1995" "1996" "1997" "1998" "1999" "2000"
# ...

# %% [markdown]
# * Na
# * films that start after current year (2020), may be removed

# %%
nrow(tb_clean[tb_clean$startYear=="\\N",])/nrow(tb_clean)
# Out:
# [1] 0.06107598

# %%
# remove NA
tb_clean = tb_clean[tb_clean$startYear!="\\N",]
tb_clean$startYear = factor(tb_clean$startYear)

# %%
# convert to numeric type
tb_clean$startYear = as.numeric(as.character(tb_clean$startYear))

# %%
head(tb_clean)
# Out:
#   tconst    titleType isAdult startYear endYear runtimeMinutes
# 1 tt0000001 short     0       1894      \\N     1
# 2 tt0000002 short     0       1892      \\N     5
# 3 tt0000003 short     0       1892      \\N     4
# 4 tt0000004 short     0       1892      \\N     12
# 5 tt0000005 short     0       1893      \\N     1
# 6 tt0000006 short     0       1894      \\N     1
#   genres
# 1 Documentary,Short
# 2 Animation,Short
# 3 Animation,Comedy,Romance
# 4 Animation,Short
# 5 Comedy,Short
# 6 Short

# %%
ggplot(tb_clean, aes(x=startYear)) + geom_boxplot()
# Out:
# plot without title
