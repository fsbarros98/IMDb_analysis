# %% [markdown]
# # Hipothesis - Titles' Success
# ## Titles Awards

# %%
#libraries
library(ggplot2)
library(dplyr) 
library(tidyverse)
library(stringr)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  3.0.4     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#load datasets

# %%
title_basics=read.delim("./../dataset/title_basics_cleaned_withtitle.tsv",header=TRUE)

# %%
golden_globes = read.csv("./../dataset/golden_globe_awards.csv",header=TRUE)

# %%
emmy_awards = read.csv("./../dataset/the_emmy_awards.csv",header=TRUE)

# %%
oscars = read.csv("./../dataset/the_oscar_award.csv",header=TRUE)

# %%
head(title_basics)
# Out:
#   tconst    titleType primaryTitle           isAdult startYear runtimeMinutes
# 1 tt0000001 short     Carmencita             0       1894       1
# 2 tt0000002 short     Le clown et ses chiens 0       1892       5
# 3 tt0000003 short     Pauvre Pierrot         0       1892       4
# 4 tt0000004 short     Un bon bock            0       1892      12
# 5 tt0000005 short     Blacksmith Scene       0       1893       1
# 6 tt0000006 short     Chinese Opium Den      0       1894       1
#   genre1      genre2 genre3
# 1 Documentary Short  0
# 2 Animation   Short  0
# 3 Animation   Comedy Romance
# 4 Animation   Short  0
# 5 Comedy      Short  0
# 6 Short       0      0

# %%
head(golden_globes)
# Out:
#   year_film year_award ceremony
# 1 1943      1944       1
# 2 1943      1944       1
# 3 1943      1944       1
# 4 1943      1944       1
# 5 1943      1944       1
# 6 1943      1944       1
#   category
# 1 Best Performance by an Actress in a Supporting Role in any Motion Picture
# 2 Best Performance by an Actor in a Supporting Role in any Motion Picture
# 3 Best Director - Motion Picture
# 4 Picture
# 5 Actress In A Leading Role
# 6 Actor In A Leading Role
#   nominee                film                    win
# 1 Katina Paxinou         For Whom The Bell Tolls True
# 2 Akim Tamiroff          For Whom The Bell Tolls True
# 3 Henry King             The Song Of Bernadette  True
# 4 The Song Of Bernadette                         True
# 5 Jennifer Jones         The Song Of Bernadette  True
# 6 Paul Lukas             Watch On The Rhine      True

# %%
head(emmy_awards)
# Out:
#   id startYear
# 1 1  2019
# 2 2  2019
# 3 3  2019
# 4 4  2019
# 5 5  2019
# 6 6  2019
#   category
# 1 Outstanding Character Voice-Over Performance
# 2 Outstanding Character Voice-Over Performance
# 3 Outstanding Character Voice-Over Performance
# 4 Outstanding Character Voice-Over Performance
# 5 Outstanding Production Design For A Narrative Contemporary Program (One Hour Or More)
# 6 Outstanding Production Design For A Narrative Contemporary Program (One Hour Or More)
#   primaryTitle
# 1 The Simpsons
# 2 Family Guy
# 3 When You Wish Upon A Pickle: A Sesame Street Special
# 4 F Is For Family
# 5 Escape At Dannemora
# 6 Killing Eve
#   staff
# 1 Hank Azaria, as Moe, Carl, Duffman, Kirk
# 2 Alex Borstein, as Lois Griffin, Tricia Takanawa
# 3 Eric Jacobson, as Bert, Grover, Oscar
# 4 Kevin Michael Richardson, as Rosie
# 5 Mark Ricker, Production Designer; James Truesdale, Art Director; Cherish M. Hale, Set Decorator
# 6 Laurence Dorman, Production Designer; Beckie Harvey, Art Director; Linda Wilson, Set Decorator
#   company
# 1 FOX
# 2 FOX
# 3 HBO
# 4 Netflix
# 5 Showtime
# 6 BBC America
#   producer
# 1 Gracie Films in association with 20th Century Fox Television
# 2 20th Century Fox Television
# 3 Sesame Street Workshop
# 4 Wild West Television in association with Gaumont Television
# 5 Red Hour, Busyhands, The White Mountain Company, Michael De Luca Productions, BZ Entertainment
# 6 Sid Gentle Films Ltd.
#   win
# 1 False
# 2 False
# 3 False
# 4 False
# 5 False
# 6 False

# %%
head(oscars)
# Out:
#   year_film year_ceremony ceremony category      name
# 1 1927      1928          1        ACTOR         Richard Barthelmess
# 2 1927      1928          1        ACTOR         Emil Jannings
# 3 1927      1928          1        ACTRESS       Louise Dresser
# 4 1927      1928          1        ACTRESS       Janet Gaynor
# 5 1927      1928          1        ACTRESS       Gloria Swanson
# 6 1927      1928          1        ART DIRECTION Rochus Gliese
#   film             winner
# 1 The Noose        False
# 2 The Last Command True
# 3 A Ship Comes In  False
# 4 7th Heaven       True
# 5 Sadie Thompson   False
# 6 Sunrise          False

# %% [markdown]
# ### Cleaning Emmy Awards, Golden Globes and Oscars datasets

# %%
clean_emmy = emmy_awards
clean_golden = golden_globes
clean_oscars = oscars

# %%
clean_emmy$producer=NULL
clean_emmy$id=NULL
clean_emmy$staff=NULL
clean_emmy$company=NULL
clean_emmy$staff=NULL

# %%
clean_emmy$win = as.integer(as.logical(clean_emmy$win))
unique(clean_emmy$win)
# Out:
# [1] 0 1

# %%
colnames(clean_emmy) = c("startYear","category_emmy","primaryTitle","win_emmy")

# %%
clean_golden$ceremony=NULL
#clean_golden$year_award=NULL
clean_golden$win = as.integer(as.logical(clean_golden$win))
unique(clean_golden$win)
# Out:
# [1] 1 0

# %%
colnames(clean_golden) = c("startYear","year_cerimony_gg","category_gg","nominee","film","win_gg")
head(clean_golden)
# Out:
#   startYear year_cerimony_gg
# 1 1943      1944
# 2 1943      1944
# 3 1943      1944
# 4 1943      1944
# 5 1943      1944
# 6 1943      1944
#   category_gg
# 1 Best Performance by an Actress in a Supporting Role in any Motion Picture
# 2 Best Performance by an Actor in a Supporting Role in any Motion Picture
# 3 Best Director - Motion Picture
# 4 Picture
# 5 Actress In A Leading Role
# 6 Actor In A Leading Role
#   nominee                film                    win_gg
# 1 Katina Paxinou         For Whom The Bell Tolls 1
# 2 Akim Tamiroff          For Whom The Bell Tolls 1
# 3 Henry King             The Song Of Bernadette  1
# 4 The Song Of Bernadette                         1
# 5 Jennifer Jones         The Song Of Bernadette  1
# 6 Paul Lukas             Watch On The Rhine      1

# %%
clean_oscars$ceremony = NULL
clean_oscars$winner = as.integer(as.logical(clean_oscars$winner))
unique(clean_oscars$winner)
colnames(clean_oscars) = c("startYear","year_cerimony_oscars","category_oscars","name","primaryTitle","win_oscars")
head(clean_oscars)
# Out:
# [1] 0 1
#   startYear year_cerimony_oscars category_oscars name
# 1 1927      1928                 ACTOR           Richard Barthelmess
# 2 1927      1928                 ACTOR           Emil Jannings
# 3 1927      1928                 ACTRESS         Louise Dresser
# 4 1927      1928                 ACTRESS         Janet Gaynor
# 5 1927      1928                 ACTRESS         Gloria Swanson
# 6 1927      1928                 ART DIRECTION   Rochus Gliese
#   primaryTitle     win_oscars
# 1 The Noose        0
# 2 The Last Command 1
# 3 A Ship Comes In  0
# 4 7th Heaven       1
# 5 Sadie Thompson   0
# 6 Sunrise          0

# %%
#remove instances with no primaryTitle
nrow(clean_oscars[clean_oscars$primaryTitle=='',])
clean_oscars = clean_oscars[clean_oscars$primaryTitle != '',]
nrow(clean_oscars[clean_oscars$primaryTitle=='',])
nrow(clean_oscars[clean_oscars$primaryTitle=='//N',])
# Out:
# [1] 304
# [1] 0
# [1] 0

# %% [markdown]
# ### Check how much complementary information we have

# %%
# between title basics and emmy awards
titles_year = title_basics %>% select(3,5)

# %%
head(titles_year)
# Out:
#   primaryTitle           startYear
# 1 Carmencita             1894
# 2 Le clown et ses chiens 1892
# 3 Pauvre Pierrot         1892
# 4 Un bon bock            1892
# 5 Blacksmith Scene       1893
# 6 Chinese Opium Den      1894

# %%
nrow(titles_year)
# Out:
# [1] 1231356

# %%
summary(as.factor(clean_emmy$win_emmy))
# Out:
#     0     1
# 16586  4917

# %%
titles_year_emmys = left_join(titles_year,clean_emmy,by=c("primaryTitle","startYear"))

# %%
head(titles_year_emmys)
# Out:
#   primaryTitle           startYear category_emmy win_emmy
# 1 Carmencita             1894      NA            NA
# 2 Le clown et ses chiens 1892      NA            NA
# 3 Pauvre Pierrot         1892      NA            NA
# 4 Un bon bock            1892      NA            NA
# 5 Blacksmith Scene       1893      NA            NA
# 6 Chinese Opium Den      1894      NA            NA

# %%
nrow(titles_year_emmys)
# Out:
# [1] 1232575

# %%
sum(is.na(titles_year_emmys$win_emmy))
# Out:
# [1] 1230693

# %%
1329629 - 1327980
# Out:
# [1] 1649

# %%
nrow(clean_emmy)
# Out:
# [1] 21503

# %% [markdown]
#  - we have 1649 correspondences between our title basics and emmys dataset

# %%
# between title basics and golden globes
#first, transform the film column into primary title, 
#adding values of nominee when it is missing
nrow(clean_golden[clean_golden$film=="",])
# Out:
# [1] 1800

# %%
nrow(clean_golden)
# Out:
# [1] 7991

# %%
#let's separate this dataset into 
#golden globes for people vs. golden globes for movies
clean_gg_films = subset(clean_golden,film == "")
clean_gg_people = subset(clean_golden,film!= "")

# %%
nrow(clean_gg_films)
# Out:
# [1] 1800

# %%
nrow(clean_gg_people)
# Out:
# [1] 6191

# %%
clean_gg_films$film =NULL
colnames(clean_gg_films) = c("startYear","year_cerimony_gg","category_gg_film","primaryTitle","win_gg_film")
head(clean_gg_films)
# Out:
#    startYear year_cerimony_gg category_gg_film primaryTitle
# 4  1943      1944             Picture          The Song Of Bernadette
# 10 1944      1945             Picture          Going My Way
# 17 1945      1946             Picture          The Lost Weekend
# 25 1946      1947             Picture          The Best Years Of Our Lives
# 36 1947      1948             Picture          Gentleman's Agreement
# 47 1948      1949             Picture          Johnny Belinda
#    win_gg_film
# 4  1
# 10 1
# 17 1
# 25 1
# 36 1
# 47 1

# %% [markdown]
#  - this dataset also contains data from series and tvshows, but these will be erased when merging

# %%
titles_year_gg_films = left_join(titles_year,clean_gg_films,by=c("primaryTitle","startYear"))

# %%
nrow(titles_year_gg_films)
# Out:
# [1] 1231356

# %%
sum(is.na(titles_year_gg_films$win_gg_film))
# Out:
# [1] 1230611

# %%
1328553-1327826
# Out:
# [1] 727

# %% [markdown]
#  - we have 727 correspondences

# %%
head(titles_year_gg_films)
# Out:
#   primaryTitle           startYear year_cerimony_gg category_gg_film
# 1 Carmencita             1894      NA               NA
# 2 Le clown et ses chiens 1892      NA               NA
# 3 Pauvre Pierrot         1892      NA               NA
# 4 Un bon bock            1892      NA               NA
# 5 Blacksmith Scene       1893      NA               NA
# 6 Chinese Opium Den      1894      NA               NA
#   win_gg_film
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
#for the peoples dataset
colnames(clean_gg_people) = c("startYear","year_cerimony_gg","category_gg_people","nominee","primaryTitle","win_gg_people")
head(clean_gg_people)
# Out:
#   startYear year_cerimony_gg
# 1 1943      1944
# 2 1943      1944
# 3 1943      1944
# 5 1943      1944
# 6 1943      1944
# 7 1944      1945
#   category_gg_people
# 1 Best Performance by an Actress in a Supporting Role in any Motion Picture
# 2 Best Performance by an Actor in a Supporting Role in any Motion Picture
# 3 Best Director - Motion Picture
# 5 Actress In A Leading Role
# 6 Actor In A Leading Role
# 7 Best Performance by an Actress in a Supporting Role in any Motion Picture
#   nominee         primaryTitle            win_gg_people
# 1 Katina Paxinou  For Whom The Bell Tolls 1
# 2 Akim Tamiroff   For Whom The Bell Tolls 1
# 3 Henry King      The Song Of Bernadette  1
# 5 Jennifer Jones  The Song Of Bernadette  1
# 6 Paul Lukas      Watch On The Rhine      1
# 7 Agnes Moorehead Mrs. Parkington         1

# %%
titles_year_gg_people = left_join(titles_year,clean_gg_people,by=c("primaryTitle","startYear"))

# %%
nrow(titles_year_gg_people)
# Out:
# [1] 1232826

# %%
sum(is.na(titles_year_gg_people$win_gg_people))
# Out:
# [1] 1229693

# %%
1330005-1326924
# Out:
# [1] 3081

# %% [markdown]
#  - we have 3081 correspondences

# %%
summary(as.factor(clean_oscars$win_oscars))
# Out:
#    0    1
# 8012 2079

# %%
titles_year_oscars = left_join(titles_year,clean_oscars,by=c("primaryTitle","startYear"))

# %%
head(titles_year_oscars)
# Out:
#   primaryTitle           startYear year_cerimony_oscars category_oscars name
# 1 Carmencita             1894      NA                   NA              NA
# 2 Le clown et ses chiens 1892      NA                   NA              NA
# 3 Pauvre Pierrot         1892      NA                   NA              NA
# 4 Un bon bock            1892      NA                   NA              NA
# 5 Blacksmith Scene       1893      NA                   NA              NA
# 6 Chinese Opium Den      1894      NA                   NA              NA
#   win_oscars
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
nrow(titles_year_oscars)
# Out:
# [1] 1236281

# %%
nrow(clean_oscars)
# Out:
# [1] 10091

# %%
sum(is.na(titles_year_oscars$win_oscars))
# Out:
# [1] 1227284

# %%
1236281-1227284
# Out:
# [1] 8997

# %% [markdown]
#  - we have 8997 correspondences between our title basics and oscars datasets

# %% [markdown]
# ## Now let's merge all this data into one big dataset according to title basics!

# %%
titlebasics_emmys = left_join(title_basics,clean_emmy,by=c("primaryTitle","startYear"))

# %%
titlebasics_emmys_ggfilms = left_join(titlebasics_emmys,clean_gg_films,by=c("primaryTitle","startYear"))

# %%
titlebasics_emmys_ggfilms_ggpeople = left_join(titlebasics_emmys_ggfilms,clean_gg_people,by=c("primaryTitle","startYear"))

# %%
titlebasics_awards = left_join(titlebasics_emmys_ggfilms_ggpeople,clean_oscars,by=c("primaryTitle","startYear"))

# %%
#verify correspondences
#emmys
nrow(titlebasics_emmys) - sum(is.na(titlebasics_emmys$win_emmy))
#gg films
nrow(titlebasics_emmys_ggfilms) - sum(is.na(titlebasics_emmys_ggfilms$win_gg_film))
#gg people
nrow(titlebasics_awards) - sum(is.na(titlebasics_awards$win_gg_people))
# Out:
# [1] 1882
# [1] 1222
# [1] 12921

# %% [markdown]
#  - repeated values are added at each instance (so we will have multiple instances for same movie but different categories or awards)

# %%
options(repr.matrix.max.cols=150, repr.matrix.max.rows=200)

head(titlebasics_awards)
# Out:
#   tconst    titleType primaryTitle           isAdult startYear runtimeMinutes
# 1 tt0000001 short     Carmencita             0       1894       1
# 2 tt0000002 short     Le clown et ses chiens 0       1892       5
# 3 tt0000003 short     Pauvre Pierrot         0       1892       4
# 4 tt0000004 short     Un bon bock            0       1892      12
# 5 tt0000005 short     Blacksmith Scene       0       1893       1
# 6 tt0000006 short     Chinese Opium Den      0       1894       1
#   genre1      genre2 genre3  category_emmy win_emmy year_cerimony_gg.x
# 1 Documentary Short  0       NA            NA       NA
# 2 Animation   Short  0       NA            NA       NA
# 3 Animation   Comedy Romance NA            NA       NA
# 4 Animation   Short  0       NA            NA       NA
# 5 Comedy      Short  0       NA            NA       NA
# 6 Short       0      0       NA            NA       NA
#   category_gg_film win_gg_film year_cerimony_gg.y category_gg_people nominee
# 1 NA               NA          NA                 NA                 NA
# 2 NA               NA          NA                 NA                 NA
# 3 NA               NA          NA                 NA                 NA
# 4 NA               NA          NA                 NA                 NA
# 5 NA               NA          NA                 NA                 NA
# 6 NA               NA          NA                 NA                 NA
#   win_gg_people year_cerimony_oscars category_oscars name win_oscars
# 1 NA            NA                   NA              NA   NA
# 2 NA            NA                   NA              NA   NA
# 3 NA            NA                   NA              NA   NA
# 4 NA            NA                   NA              NA   NA
# 5 NA            NA                   NA              NA   NA
# 6 NA            NA                   NA              NA   NA

# %%
nrow(titlebasics_awards)
# Out:
# [1] 1245516

# %%
nrow(title_basics)
# Out:
# [1] 1231356

# %%
titlebasics_awards
# Out:
#         tconst    titleType
# 1       tt0000001 short
# 2       tt0000002 short
# 3       tt0000003 short
# 4       tt0000004 short
# 5       tt0000005 short
# 6       tt0000006 short
# 7       tt0000007 short
# 8       tt0000008 short
# 9       tt0000009 movie
# 10      tt0000010 short
# 11      tt0000011 short
# 12      tt0000012 short
# 13      tt0000013 short
# 14      tt0000014 short
# 15      tt0000015 short
# 16      tt0000016 short
# 17      tt0000017 short
# 18      tt0000018 short
# 19      tt0000019 short
# 20      tt0000020 short
# 21      tt0000022 short
# 22      tt0000023 short
# 23      tt0000024 short
# 24      tt0000025 short
# 1245479 NA                   NA              NA   NA
# 1245480 NA                   NA              NA   NA
# 1245481 NA                   NA              NA   NA
# 1245482 NA                   NA              NA   NA
# 1245483 NA                   NA              NA   NA
# 1245484 NA                   NA              NA   NA
# 1245485 NA                   NA              NA   NA
# 1245486 NA                   NA              NA   NA
# 1245487 NA                   NA              NA   NA
# 1245488 NA                   NA              NA   NA
# 1245489 NA                   NA              NA   NA
# 1245490 NA                   NA              NA   NA
# 1245491 NA                   NA              NA   NA
# 1245492 NA                   NA              NA   NA
# 1245493 NA                   NA              NA   NA
# 1245494 NA                   NA              NA   NA
# 1245495 NA                   NA              NA   NA
# 1245496 NA                   NA              NA   NA
# 1245497 NA                   NA              NA   NA
# 1245498 NA                   NA              NA   NA
# 1245499 NA                   NA              NA   NA
# 1245500 NA                   NA              NA   NA
# 1245501 NA                   NA              NA   NA
# 1245502 NA                   NA              NA   NA
# 1245503 NA                   NA              NA   NA
# 1245504 NA                   NA              NA   NA
# 1245505 NA                   NA              NA   NA
# 1245506 NA                   NA              NA   NA
# 1245507 NA                   NA              NA   NA
# 1245508 NA                   NA              NA   NA
# 1245509 NA                   NA              NA   NA
# 1245510 NA                   NA              NA   NA
# 1245511 NA                   NA              NA   NA
# 1245512 NA                   NA              NA   NA
# 1245513 NA                   NA              NA   NA
# 1245514 NA                   NA              NA   NA
# 1245515 NA                   NA              NA   NA
# 1245516 NA                   NA              NA   NA

# %% [markdown]
#  - most of the rows will be of no interest, but now we need to compare with title ratings!

# %% [markdown]
# ## Do high rated movies get awards ?

# %%
# first - merge titlebasics_awards with title ratings
#load title ratings
title_ratings=read.delim("./../dataset/filtered_title_ratings.tsv",header=TRUE)

# %%
nrow(title_ratings)
head(title_ratings)
# Out:
# [1] 423183
#   tconst    averageRating numVotes
# 1 tt0000001 5.6           1654
# 2 tt0000002 6.1            199
# 3 tt0000003 6.5           1366
# 4 tt0000004 6.2            121
# 5 tt0000005 6.2           2149
# 6 tt0000006 5.3            115

# %%
#the merge will be made by tconst
#we want to keep all the instances in every dataset,
#so we do a fair comparison
title_awards_ratings = full_join(titlebasics_awards,title_ratings,by="tconst")

# %%
nrow(title_awards_ratings)
# Out:
# [1] 1262271

# %%
1251290-1234535
# Out:
# [1] 16755

# %% [markdown]
#  - we have 16 755 more instances than before the merge, this means that 16 755 have ratings instances, but not title basics instances, probably due to cleaning steps, such as removing NA values with no startYear, for instance

# %%
head(title_awards_ratings)
# Out:
#   tconst    titleType primaryTitle           isAdult startYear runtimeMinutes
# 1 tt0000001 short     Carmencita             0       1894       1
# 2 tt0000002 short     Le clown et ses chiens 0       1892       5
# 3 tt0000003 short     Pauvre Pierrot         0       1892       4
# 4 tt0000004 short     Un bon bock            0       1892      12
# 5 tt0000005 short     Blacksmith Scene       0       1893       1
# 6 tt0000006 short     Chinese Opium Den      0       1894       1
#   genre1      genre2 genre3  category_emmy win_emmy year_cerimony_gg.x
# 1 Documentary Short  0       NA            NA       NA
# 2 Animation   Short  0       NA            NA       NA
# 3 Animation   Comedy Romance NA            NA       NA
# 4 Animation   Short  0       NA            NA       NA
# 5 Comedy      Short  0       NA            NA       NA
# 6 Short       0      0       NA            NA       NA
#   category_gg_film win_gg_film year_cerimony_gg.y category_gg_people nominee
# 1 NA               NA          NA                 NA                 NA
# 2 NA               NA          NA                 NA                 NA
# 3 NA               NA          NA                 NA                 NA
# 4 NA               NA          NA                 NA                 NA
# 5 NA               NA          NA                 NA                 NA
# 6 NA               NA          NA                 NA                 NA
#   win_gg_people year_cerimony_oscars category_oscars name win_oscars
# 1 NA            NA                   NA              NA   NA
# 2 NA            NA                   NA              NA   NA
# 3 NA            NA                   NA              NA   NA
# 4 NA            NA                   NA              NA   NA
# 5 NA            NA                   NA              NA   NA
# 6 NA            NA                   NA              NA   NA
#   averageRating numVotes
# 1 5.6           1654
# 2 6.1            199
# 3 6.5           1366
# 4 6.2            121
# 5 6.2           2149
# 6 5.3            115

# %%
#let's save this dataset for later use (if hypotheses not completed here)
library(readr)
write_tsv(title_awards_ratings,'merged_title_basics_ratings_emmys_gg_oscars.tsv')

# %% [markdown]
# ### Let's compare the ratings of movies with at least 1 nomination vs. movies with 0 nominations
#
# To do so, we will select from title_awards_ratings only the instances with actual ratings!

# %%
#first - let's subset only one instance per tconst
ratings_only = title_awards_ratings
ratings_only = subset(ratings_only, !duplicated(ratings_only$tconst))
ratings_only = subset(ratings_only, numVotes>1000)

# %%
nrow(ratings_only)
# Out:
# [1] 34724

# %%
head(ratings_only)
ncol(ratings_only)
summary(ratings_only)
# Out:
#    tconst    titleType primaryTitle                           isAdult startYear
# 1  tt0000001 short     Carmencita                             0       1894
# 3  tt0000003 short     Pauvre Pierrot                         0       1892
# 5  tt0000005 short     Blacksmith Scene                       0       1893
# 8  tt0000008 short     Edison Kinetoscopic Record of a Sneeze 0       1894
# 10 tt0000010 short     Leaving the Factory                    0       1895
# 12 tt0000012 short     The Arrival of a Train                 0       1896
#    runtimeMinutes genre1      genre2      genre3  category_emmy win_emmy
# 1  1              Documentary Short       0       NA            NA
# 3  4              Animation   Comedy      Romance NA            NA
# 5  1              Comedy      Short       0       NA            NA
# 8  1              Documentary Short       0       NA            NA
# 10 1              Documentary Short       0       NA            NA
# 12 1              Action      Documentary Short   NA            NA
#    year_cerimony_gg.x category_gg_film win_gg_film year_cerimony_gg.y
# 1  NA                 NA               NA          NA
# 3  NA                 NA               NA          NA
# 5  NA                 NA               NA          NA
# 8  NA                 NA               NA          NA
# 10 NA                 NA               NA          NA
# 12 NA                 NA               NA          NA
#    category_gg_people nominee win_gg_people year_cerimony_oscars
# 1  NA                 NA      NA            NA
# 3  NA                 NA      NA            NA
# 5  NA                 NA      NA            NA
# 8  NA                 NA      NA            NA
# 10 NA                 NA      NA            NA
# 12 NA                 NA      NA            NA
#    category_oscars name win_oscars averageRating numVotes
# 1  NA              NA   NA         5.6            1654
# 3  NA              NA   NA         6.5            1366
# 5  NA              NA   NA         6.2            2149
# 8  NA              NA   NA         5.4            1821
# 10 NA              NA   NA         6.9            6074
# 12 NA              NA   NA         7.4           10395
# [1] 24
#        tconst        titleType                            primaryTitle
#  tt0000001:    1   movie  :31562   Mother                       :    8
#  tt0000003:    1   short  : 1029   Cinderella                   :    7
#  tt0000005:    1   tvMovie: 1725   Hamlet                       :    7
#  tt0000008:    1   NA's   :  408   Les Misérables               :    7
#  tt0000010:    1                   The Hound of the Baskervilles:    7
#  tt0000012:    1                   (Other)                      :34280
#  (Other)  :34718                   NA's                         :  408
#     isAdult        startYear    runtimeMinutes        genre1
#  Min.   :0e+00   Min.   :1874   Min.   : -1.0   Comedy   :9308
#  1st Qu.:0e+00   1st Qu.:1986   1st Qu.: 90.0   Drama    :7910
#  Median :0e+00   Median :2004   Median : 99.0   Action   :6177
#  Mean   :6e-04   Mean   :1996   Mean   :101.8   Crime    :2394
#  3rd Qu.:0e+00   3rd Qu.:2013   3rd Qu.:113.0   Adventure:2036
#  Max.   :1e+00   Max.   :2019   Max.   :729.0   (Other)  :6491
#  NA's   :408     NA's   :408    NA's   :408     NA's     : 408
#      genre2           genre3
#  Drama  : 8232   0       :16660
#  0      : 6007   Thriller: 2957
#  Romance: 2972   Romance : 2943
#  Crime  : 2289   Drama   : 2222
#  Comedy : 2056   Mystery : 1135
#  (Other):12760   (Other) : 8399
#  NA's   :  408   NA's    :  408
#                                                         category_emmy
#  Outstanding Lead Actress In A Miniseries Or A Movie           :   15
#  Outstanding Lead Actor In A Miniseries Or A Movie             :    8
#  Outstanding Sound Editing For A Miniseries, Movie Or A Special:    3
#  Outstanding Supporting Actress In A Miniseries Or A Movie     :    3
#  Exceptional Merit In Documentary Filmmaking                   :    2
#  (Other)                                                       :   72
#  NA's                                                          :34621
#     win_emmy     year_cerimony_gg.x
#  Min.   :0.00    Min.   :1945
#  1st Qu.:0.00    1st Qu.:1976
#  Median :0.00    Median :1995
#  Mean   :0.14    Mean   :1992
#  3rd Qu.:0.00    3rd Qu.:2009
#  Max.   :1.00    Max.   :2020
#  NA's   :34621   NA's   :34144
#                                                              category_gg_film
#  Best Motion Picture - Drama                                         :  231
#  Best Motion Picture - Musical or Comedy                             :  214
#  Best Motion Picture - Animated                                      :   47
#  Best Television Limited Series or Motion Picture Made for Television:   45
#  Picture - Comedy                                                    :   13
#  (Other)                                                             :   30
#  NA's                                                                :34144
#   win_gg_film    year_cerimony_gg.y
#  Min.   :0.00    Min.   :1945
#  1st Qu.:0.00    1st Qu.:1974
#  Median :0.00    Median :1992
#  Mean   :0.23    Mean   :1990
#  3rd Qu.:0.00    3rd Qu.:2006
#  Max.   :1.00    Max.   :2020
#  NA's   :34144   NA's   :33446
#                                                               category_gg_people
#  Best Performance by an Actress in a Motion Picture - Drama            :  203
#  Best Performance by an Actor in a Motion Picture - Drama              :  186
#  Best Performance by an Actress in a Motion Picture - Musical or Comedy:  172
#  Best Performance by an Actor in a Motion Picture - Musical or Comedy  :  150
#  Best Original Song - Motion Picture                                   :   91
#  (Other)                                                               :  476
#  NA's                                                                  :33446
#              nominee      win_gg_people   year_cerimony_oscars
#  Meryl Streep    :   16   Min.   :0.00    Min.   :1928
#  Al Pacino       :   11   1st Qu.:0.00    1st Qu.:1958
#  Nicole Kidman   :   10   Median :0.00    Median :1985
#  Shirley MacLaine:   10   Mean   :0.24    Mean   :1981
#  Dustin Hoffman  :    9   3rd Qu.:0.00    3rd Qu.:2005
#  (Other)         : 1222   Max.   :1.00    Max.   :2020
#  NA's            :33446   NA's   :33446   NA's   :32129
#                    category_oscars                     name
#  ACTOR IN A SUPPORTING ROLE:  243   France               :   20
#  ACTOR IN A LEADING ROLE   :  203   Meryl Streep         :   15
#  ACTOR                     :  175   John Williams        :   12
#  FOREIGN LANGUAGE FILM     :  151   Walt Disney, Producer:   12
#  ACTRESS IN A LEADING ROLE :  145   Jack Nicholson       :    9
#  (Other)                   : 1678   (Other)              : 2527
#  NA's                      :32129   NA's                 :32129
#    win_oscars    averageRating      numVotes
#  Min.   :0.00    Min.   :1.000   Min.   :   1001
#  1st Qu.:0.00    1st Qu.:5.800   1st Qu.:   1627
#  Median :0.00    Median :6.600   Median :   3205
#  Mean   :0.18    Mean   :6.393   Mean   :  23720
#  3rd Qu.:0.00    3rd Qu.:7.200   3rd Qu.:  10369
#  Max.   :1.00    Max.   :9.800   Max.   :2296829
#  NA's   :32129

# %%
ratings_only = ratings_only[complete.cases(ratings_only[,23]),]
nrow(ratings_only)
# Out:
# [1] 34724

# %%
head(ratings_only)
# Out:
#    tconst    titleType primaryTitle                           isAdult startYear
# 1  tt0000001 short     Carmencita                             0       1894
# 3  tt0000003 short     Pauvre Pierrot                         0       1892
# 5  tt0000005 short     Blacksmith Scene                       0       1893
# 8  tt0000008 short     Edison Kinetoscopic Record of a Sneeze 0       1894
# 10 tt0000010 short     Leaving the Factory                    0       1895
# 12 tt0000012 short     The Arrival of a Train                 0       1896
#    runtimeMinutes genre1      genre2      genre3  category_emmy win_emmy
# 1  1              Documentary Short       0       NA            NA
# 3  4              Animation   Comedy      Romance NA            NA
# 5  1              Comedy      Short       0       NA            NA
# 8  1              Documentary Short       0       NA            NA
# 10 1              Documentary Short       0       NA            NA
# 12 1              Action      Documentary Short   NA            NA
#    year_cerimony_gg.x category_gg_film win_gg_film year_cerimony_gg.y
# 1  NA                 NA               NA          NA
# 3  NA                 NA               NA          NA
# 5  NA                 NA               NA          NA
# 8  NA                 NA               NA          NA
# 10 NA                 NA               NA          NA
# 12 NA                 NA               NA          NA
#    category_gg_people nominee win_gg_people year_cerimony_oscars
# 1  NA                 NA      NA            NA
# 3  NA                 NA      NA            NA
# 5  NA                 NA      NA            NA
# 8  NA                 NA      NA            NA
# 10 NA                 NA      NA            NA
# 12 NA                 NA      NA            NA
#    category_oscars name win_oscars averageRating numVotes
# 1  NA              NA   NA         5.6            1654
# 3  NA              NA   NA         6.5            1366
# 5  NA              NA   NA         6.2            2149
# 8  NA              NA   NA         5.4            1821
# 10 NA              NA   NA         6.9            6074
# 12 NA              NA   NA         7.4           10395

# %%
zero_nomination_ratings = ratings_only[is.na(ratings_only$win_emmy & ratings_only$win_gg_film & ratings_only$win_gg_people & ratings_only$win_oscars),]

# %%
nrow(zero_nomination_ratings)
# Out:
# [1] 31998

# %%
one_plus_nomination_ratings = ratings_only[!is.na(ratings_only$win_emmy & ratings_only$win_gg_film & ratings_only$win_gg_people & ratings_only$win_oscars),]

# %%
nrow(one_plus_nomination_ratings)
# Out:
# [1] 2726

# %%
31998+2726
# Out:
# [1] 34724

# %%
one_plus_winning_ratings = one_plus_nomination_ratings[which(ratings_only$win_emmy == 1 | ratings_only$win_gg_film == 1|ratings_only$win_gg_people == 1|ratings_only$win_oscars == 1),]

# %%
wins_emmys = one_plus_nomination_ratings[which(ratings_only$win_emmy == 1),]
wins_gg_people = one_plus_nomination_ratings[which(ratings_only$win_gg_people == 1),]
wins_gg_film = one_plus_nomination_ratings[which(ratings_only$win_gg_film == 1),]
wins_oscars = one_plus_nomination_ratings[which(ratings_only$win_oscars == 1),]
nrow(wins_emmys)
nrow(wins_gg_people)
nrow(wins_gg_film)
nrow(wins_oscars)
# Out:
# [1] 14
# [1] 310
# [1] 135
# [1] 469

# %%
nrow(one_plus_winning_ratings)
# Out:
# [1] 738

# %%
14+310+135+469
# Out:
# [1] 928

# %%
#let's plot the distribution of ratings of these two datasets

# %%
mean_rating_zero_nomination =mean(zero_nomination_ratings$averageRating,na.rm=TRUE)
mean_rating_one_plus_nomination =mean(one_plus_nomination_ratings$averageRating,na.rm=TRUE)
mean_rating_one_plus_winning =mean(one_plus_winning_ratings$averageRating,na.rm=TRUE)

# %%
xs = c("0","1","2")
means = c(mean_rating_zero_nomination,mean_rating_one_plus_nomination,mean_rating_one_plus_winning)
means_df = data.frame(xs,means)

# %%
means_df
# Out:
#   xs means
# 1 0  6.329461
# 2 1  7.137271
# 3 2  7.130000

# %%
plot_dist = qplot()+
geom_violin(data=zero_nomination_ratings, aes(x="0",y=averageRating),fill="skyblue1",color="skyblue1")+
geom_boxplot(data=zero_nomination_ratings, aes(x="0",y=averageRating),width=0.6,fill="white",color="black")+
geom_violin(data=one_plus_nomination_ratings,aes(x="1",y=averageRating),fill="skyblue2",color="skyblue2")+
geom_boxplot(data=one_plus_nomination_ratings,aes(x="1",y=averageRating),width=0.2,fill="white",color="black")+
geom_violin(data=one_plus_winning_ratings,aes(x="2",y=averageRating),fill="skyblue3",color="skyblue3")+
geom_boxplot(data=one_plus_winning_ratings,aes(x="2",y=averageRating),width=0.17,fill="white",color="black")+
geom_point(data=means_df,aes(x=xs,y=means,color="red4",size=4,),show.legend = FALSE)+
geom_text(data=means_df,aes(x=xs,y=means,label=round(means_df$means,digits=2)),hjust=0.5, vjust=-1.3)+
geom_line(data=means_df,aes(x=xs,y=means,color="red4"),group=1,show.legend = FALSE)+
scale_x_discrete(labels=c("2"="≥1 Wins \n (738)","1"="≥1 Nominations \n (2726)","0"="0 Nominations \n (31998)"))+
scale_y_continuous(breaks=seq(0,10,1))+
labs(y=expression("Average Rating"),x="")+
theme_bw(base_size = 19)+
theme(axis.text.y = element_text(angle = 90, vjust = 0.5, hjust=0.5))

# %%
plot_dist
# Out:
# Warning message:
# “Removed 588 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 588 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
ggsave(plot=plot_dist,file="distribution_ratings_nominations_awards.png",width=8,height=8,dpi=300)
# Out:
# Warning message:
# “Removed 588 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 588 rows containing non-finite values (stat_boxplot).”

# %% [markdown]
#  - movies with nominations and awards have higher ratings!

# %% [markdown]
# ## How do wins distribute over the genres?

# %%
genres_experiments = title_awards_ratings

# %%
genres_winnings = genres_experiments[which(genres_experiments$win_emmy == 1 | genres_experiments$win_gg_film == 1| genres_experiments$win_gg_people == 1 | genres_experiments$win_oscars ==1),]
nrow(genres_winnings)
head(genres_winnings)
# Out:
# [1] 8615
#       tconst    titleType primaryTitle isAdult startYear runtimeMinutes genre1
# 16376 tt0018379 movie     7th Heaven   0       1927      110            Drama
# 16378 tt0018379 movie     7th Heaven   0       1927      110            Drama
# 16380 tt0018379 movie     7th Heaven   0       1927      110            Drama
# 16447 tt0018455 movie     Sunrise      0       1927       94            Drama
# 16448 tt0018455 movie     Sunrise      0       1927       94            Drama
# 16449 tt0018455 movie     Sunrise      0       1927       94            Drama
#       genre2  genre3 category_emmy win_emmy year_cerimony_gg.x category_gg_film
# 16376 Romance 0      NA            NA       NA                 NA
# 16378 Romance 0      NA            NA       NA                 NA
# 16380 Romance 0      NA            NA       NA                 NA
# 16447 Romance 0      NA            NA       NA                 NA
# 16448 Romance 0      NA            NA       NA                 NA
# 16449 Romance 0      NA            NA       NA                 NA
#       win_gg_film year_cerimony_gg.y category_gg_people nominee win_gg_people
# 16376 NA          NA                 NA                 NA      NA
# 16378 NA          NA                 NA                 NA      NA
# 16380 NA          NA                 NA                 NA      NA
# 16447 NA          NA                 NA                 NA      NA
# 16448 NA          NA                 NA                 NA      NA
# 16449 NA          NA                 NA                 NA      NA
#       year_cerimony_oscars category_oscars              name
# 16376 1928                 ACTRESS                      Janet Gaynor
# 16378 1928                 DIRECTING (Dramatic Picture) Frank Borzage
# 16380 1928                 WRITING (Adaptation)         Benjamin Glazer
# 16447 1928                 CINEMATOGRAPHY               Charles Rosher
# 16448 1928                 CINEMATOGRAPHY               Karl Struss
# 16449 1928                 UNIQUE AND ARTISTIC PICTURE  Fox
#       win_oscars averageRating numVotes
# 16376 1          7.6            3135
# 16378 1          7.6            3135
# 16380 1          7.6            3135
# 16447 1          8.1           46354
# 16448 1          8.1           46354
# 16449 1          8.1           46354

# %%
#let's separate into 1 genre only, 2 genre and 3 genre

# %%
genres1_winnings = genres_winnings[which(genres_winnings$genre2 ==0 & genres_winnings$genre3 ==0),]
nrow(genres1_winnings)
# Out:
# [1] 1111

# %%
genres2_winnings = genres_winnings[which(genres_winnings$genre2 != 0 & genres_winnings$genre3 ==0),]
nrow(genres2_winnings)
# Out:
# [1] 2633

# %%
genres3_winnings = genres_winnings[which(genres_winnings$genre2 != 0 & genres_winnings$genre3 !=0),]
nrow(genres3_winnings)
# Out:
# [1] 4871

# %%
genres1_winnings_count_genre1 = genres1_winnings %>% count(genre1)
genres1_winnings_count_genre1 = arrange(genres1_winnings_count_genre1,n)
colnames(genres1_winnings_count_genre1) = c("genre","n_1")
genres1_winnings_count_genre1
# Out:
#    genre       n_1
# 1  Action        1
# 2  Adult         1
# 3  Western       2
# 4  Musical       3
# 5  Animation     5
# 6  Horror        7
# 7  Crime         9
# 8  Comedy       30
# 9  Documentary  33
# 10 Thriller     50
# 11 Short        91
# 12 Drama       879

# %%
genres2_winnings_count_genre1 = genres2_winnings %>% count(genre1)
colnames(genres2_winnings_count_genre1) = c("genre","n_1")
genres2_winnings_count_genre2 = genres2_winnings %>% count(genre2)
colnames(genres2_winnings_count_genre2) = c("genre","n_2")


genres2 = full_join(genres2_winnings_count_genre1,genres2_winnings_count_genre2,by="genre")
genres2_n = genres2 %>% select(2,3)
genres2_n = rowSums(genres2_n,na.rm=TRUE)

genres2$n = genres2_n
genres2$n_1=NULL
genres2$n_2=NULL
genres2_wins = arrange(genres2,n)
genres2_wins
# Out:
#    genre       n
# 1  News           2
# 2  Animation     13
# 3  Mystery       14
# 4  Sci-Fi        19
# 5  Film-Noir     20
# 6  Fantasy       22
# 7  Adventure     27
# 8  History       29
# 9  Horror        30
# 10 Family        39
# 11 Music         39
# 12 Action        46
# 13 Western       70
# 14 Thriller      93
# 15 Musical       95
# 16 Sport         98
# 17 Documentary  114
# 18 Crime        130
# 19 War          182
# 20 Biography    297
# 21 Comedy       366
# 22 Short        408
# 23 Romance      899
# 24 Drama       2214

# %%
genres3_winnings_count_genre1 = genres3_winnings %>% count(genre1)
colnames(genres3_winnings_count_genre1) = c("genre","n_1")
genres3_winnings_count_genre2 = genres3_winnings %>% count(genre2)
colnames(genres3_winnings_count_genre2) = c("genre","n_2")
genres3_winnings_count_genre3 = genres3_winnings %>% count(genre3)
colnames(genres3_winnings_count_genre3) = c("genre","n_3")

genres1_2 = full_join(genres3_winnings_count_genre1,genres3_winnings_count_genre2,by="genre")
genres3 = full_join(genres1_2,genres3_winnings_count_genre3,by="genre")
genres3_n = genres3 %>% select(2,3,4)
genres3_n = rowSums(genres3_n,na.rm=TRUE)
genres3$n = genres3_n

genres3$n_1=NULL
genres3$n_2=NULL
genres3$n_3=NULL

genres3_wins = arrange(genres3,n)
genres3_wins
# Out:
#    genre       n
# 1  Film-Noir     22
# 2  Sport         48
# 3  Western       79
# 4  Documentary   92
# 5  Sci-Fi       117
# 6  Horror       136
# 7  Animation    165
# 8  Short        196
# 9  Mystery      324
# 10 Fantasy      333
# 11 War          352
# 12 Family       353
# 13 Thriller     405
# 14 Music        410
# 15 Action       420
# 16 Musical      570
# 17 Crime        756
# 18 Adventure    873
# 19 History     1082
# 20 Romance     1105
# 21 Comedy      1342
# 22 Biography   1432
# 23 Drama       4001

# %%
#join everything together
wins_all_genres_1_2 = full_join(genres1_winnings_count_genre1,genres2_wins,by="genre")
wins_all_genres = full_join(wins_all_genres_1_2, genres3_wins,by="genre")
colnames(wins_all_genres) = c("genre","n_1","n_2","n_3")
wins_all_genres
# Out:
#    genre       n_1 n_2  n_3
# 1  Action        1   46  420
# 2  Adult         1   NA   NA
# 3  Western       2   70   79
# 4  Musical       3   95  570
# 5  Animation     5   13  165
# 6  Horror        7   30  136
# 7  Crime         9  130  756
# 8  Comedy       30  366 1342
# 9  Documentary  33  114   92
# 10 Thriller     50   93  405
# 11 Short        91  408  196
# 12 Drama       879 2214 4001
# 13 News         NA    2   NA
# 14 Mystery      NA   14  324
# 15 Sci-Fi       NA   19  117
# 16 Film-Noir    NA   20   22
# 17 Fantasy      NA   22  333
# 18 Adventure    NA   27  873
# 19 History      NA   29 1082
# 20 Family       NA   39  353
# 21 Music        NA   39  410
# 22 Sport        NA   98   48
# 23 War          NA  182  352
# 24 Biography    NA  297 1432
# 25 Romance      NA  899 1105

# %%
wins_all_genres_count = wins_all_genres
wins_all_genres_n = wins_all_genres_count %>% select(2,3,4)
wins_all_genres_n = rowSums(wins_all_genres_n,na.rm=TRUE)
wins_all_genres_count$n = wins_all_genres_n

wins_all_genres_count$n_1=NULL
wins_all_genres_count$n_2=NULL
wins_all_genres_count$n_3=NULL

wins_all_genres_count = arrange(wins_all_genres_count,n)
wins_all_genres_count
# Out:
#    genre       n
# 1  Adult          1
# 2  News           2
# 3  Film-Noir     42
# 4  Sci-Fi       136
# 5  Sport        146
# 6  Western      151
# 7  Horror       173
# 8  Animation    183
# 9  Documentary  239
# 10 Mystery      338
# 11 Fantasy      355
# 12 Family       392
# 13 Music        449
# 14 Action       467
# 15 War          534
# 16 Thriller     548
# 17 Musical      668
# 18 Short        695
# 19 Crime        895
# 20 Adventure    900
# 21 History     1111
# 22 Biography   1729
# 23 Comedy      1738
# 24 Romance     2004
# 25 Drama       7094

# %%
ggplot ()+ 
geom_point(shape=18,data=wins_all_genres_count, 
           aes(x=0,y=seq(1,nrow(wins_all_genres_count),1),
               size=n,colour=genre))  +
theme_bw(base_size = 19)
# Out:
# plot without title

# %% [markdown]
#  - let's try another visualization

# %%
label_genre = wins_all_genres_count
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$n,"  ")
nbars = nrow(label_genre)
nbars
angle = 90 - 360 * (label_genre$id) / nbars
angle
# Out:
# [1] 25
#  [1]   75.6   61.2   46.8   32.4   18.0    3.6  -10.8  -25.2  -39.6  -54.0
# [11]  -68.4  -82.8  -97.2 -111.6 -126.0 -140.4 -154.8 -169.2 -183.6 -198.0
# [21] -212.4 -226.8 -241.2 -255.6 -270.0

# %%
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)

# %%
library(pals)
pal.bands(alphabet, alphabet2, cols25, glasbey, kelly, polychrome, 
  stepped, tol, watlington,
  show.names=FALSE)
# Out:
# Only 26 colors are available with 'alphabet'
# Only 26 colors are available with 'alphabet2'
# Only 25 colors are available with 'cols25'.
# Only 32 colors are available with 'glasbey'.
# Only 22 colors are available with 'kelly'.
# Only 36 colors are available with 'polychrome'.
# Only 24 colors are available with 'stepped'
# Only 12 colors are available with 'tol'
# Only 16 colors are available with 'watlington'.
# plot without title

# %%
total_genres_plot = ggplot(wins_all_genres_count,aes(x=reorder(genre, n),y=n,fill=factor(genre))) +
geom_bar(stat="identity",show.legend=FALSE)+#,fill=alpha("skyblue3",0.5)) + 
scale_fill_manual(values=as.vector(alphabet2(25)))+
ylim(-1000,10000)+
theme_minimal()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    plot.margin = unit(rep(-1,4), "cm"))+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(wins_all_genres_count)), y=n+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=10000, label="Winning awards genres (combined)"), color="black", inherit.aes = FALSE)

# %%
total_genres_plot
# Out:
# plot without title

# %%
ggsave(plot=total_genres_plot,file="winning_awards_genres_total.png",width=7,height=10,dpi=300)

# %% [markdown]
#  - let's separate the previous plot bars into different bars per genre: movies with only 1 genre, 2 or 3

# %%
all_wins = wins_all_genres

# %%
total = all_wins %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
all_wins$total = total

# %%
colnames(all_wins) = c("genre","n_1","n_2","n_3","total")
all_wins = arrange(all_wins,total)
all_wins[is.na(all_wins)] <- 0
all_wins
# Out:
#    genre       n_1 n_2  n_3  total
# 1  Adult         1    0    0    1
# 2  News          0    2    0    2
# 3  Film-Noir     0   20   22   42
# 4  Sci-Fi        0   19  117  136
# 5  Sport         0   98   48  146
# 6  Western       2   70   79  151
# 7  Horror        7   30  136  173
# 8  Animation     5   13  165  183
# 9  Documentary  33  114   92  239
# 10 Mystery       0   14  324  338
# 11 Fantasy       0   22  333  355
# 12 Family        0   39  353  392
# 13 Music         0   39  410  449
# 14 Action        1   46  420  467
# 15 War           0  182  352  534
# 16 Thriller     50   93  405  548
# 17 Musical       3   95  570  668
# 18 Short        91  408  196  695
# 19 Crime         9  130  756  895
# 20 Adventure     0   27  873  900
# 21 History       0   29 1082 1111
# 22 Biography     0  297 1432 1729
# 23 Comedy       30  366 1342 1738
# 24 Romance       0  899 1105 2004
# 25 Drama       879 2214 4001 7094

# %%
label_genre = all_wins
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)

# %%
genres_in_awards =ggplot() + 
geom_bar(data = all_wins, aes(x=reorder(genre, total),y=n_1+n_2+n_3,fill="Three genre"), stat="identity") + 
geom_bar(data = all_wins, aes(x=reorder(genre, total),y=n_1+n_2,fill="Two genre"), stat="identity") + 
geom_bar(data = all_wins, aes(x=reorder(genre, total),y=n_1,fill="One genre"), stat="identity") + 
scale_fill_manual(values=c("#077B8A","#D72631","#5C3C92"))+
ylim(-1000,10000)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.75, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(all_wins)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=10000, label="Number of genres in winning awards"), color="black", inherit.aes = FALSE)

# %%
genres_in_awards
# Out:
# plot without title

# %%
ggsave(plot=genres_in_awards,file="genres_in_winning_awards.png",width=7,height=10,dpi=300)

# %% [markdown]
#  - now let's separate into first gender, second gender and third gender

# %%
copy_genres_winnings = genres_winnings

# %%
all_gender_winnings_columns = copy_genres_winnings %>% select(genre1,genre2,genre3)
head(all_gender_winnings_columns)
# Out:
#       genre1 genre2  genre3
# 16376 Drama  Romance 0
# 16378 Drama  Romance 0
# 16380 Drama  Romance 0
# 16447 Drama  Romance 0
# 16448 Drama  Romance 0
# 16449 Drama  Romance 0

# %%
all_wins$genre
# Out:
#  [1] Adult       News        Film-Noir   Sci-Fi      Sport       Western
#  [7] Horror      Animation   Documentary Mystery     Fantasy     Family
# [13] Music       Action      War         Thriller    Musical     Short
# [19] Crime       Adventure   History     Biography   Comedy      Romance
# [25] Drama
# 29 Levels: Action Adult Adventure Animation Biography Comedy ... 0

# %%
first_gender_counts = all_gender_winnings_columns %>% count(genre1)
colnames(first_gender_counts) = c("genre","first_genre")
second_gender_counts = all_gender_winnings_columns %>% count(genre2)
colnames(second_gender_counts) = c("genre","second_genre")
third_gender_counts = all_gender_winnings_columns %>% count(genre3)
colnames(third_gender_counts) = c("genre","third_genre")

# %%
first_second_gender_counts = full_join(first_gender_counts,second_gender_counts,by="genre")
first_second_third_gender_counts = full_join(first_second_gender_counts,third_gender_counts,by="genre")
first_second_third_gender_counts[is.na(first_second_third_gender_counts)] <- 0
total = first_second_third_gender_counts %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
first_second_third_gender_counts$total = total
first_second_third_gender_counts = first_second_third_gender_counts[first_second_third_gender_counts$genre!=0,]
first_second_third_gender_counts
# Out:
#    genre       first_genre second_genre third_genre total
# 1  Action       467           0           0          467
# 2  Adult          1           0           0            1
# 3  Adventure    610         290           0          900
# 4  Animation    102          75           6          183
# 5  Biography   1662          66           1         1729
# 6  Comedy      1353         327          58         1738
# 7  Crime        507         357          31          895
# 8  Documentary  172          60           7          239
# 9  Drama       3455        3059         580         7094
# 10 Family        16         270         106          392
# 11 Fantasy       12         145         198          355
# 12 Film-Noir      1          30          11           42
# 13 History        1         120         990         1111
# 14 Horror        42          69          62          173
# 15 Music          3         167         279          449
# 16 Musical        6         235         427          668
# 17 Mystery        3         176         159          338
# 18 Romance        2        1144         858         2004
# 19 Sci-Fi         4          44          88          136
# 20 Short        144         388         163          695
# 21 Thriller      50         129         369          548
# 22 Western        2          70          79          151
# 24 News           0           2           0            2
# 25 Sport          0          99          47          146
# 26 War            0         182         352          534

# %%
label_genre = first_second_third_gender_counts
label_genre = arrange(label_genre,total)
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)

# %%
genres_per_winning_awards = ggplot()+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre+third_genre,fill="Third Gender"),stat="identity")+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre,fill="Second Genre"), stat="identity") +
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre,fill="First Genre"),stat="identity") +
scale_fill_manual(values=c("#1e3d59","#f5f0e1","#ff6e40"))+
ylim(-1000,10000)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.75, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(first_second_third_gender_counts)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=10000, label="Genres per winnings awards"), color="black", inherit.aes = FALSE)

# %%
genres_per_winning_awards
# Out:
# plot without title

# %%
ggsave(plot=genres_per_winning_awards,file="genres_per_winning_awards.png",width=7,height=10,dpi=300)

# %% [markdown]
# ### Now let's divide this into types of awards - emmys, gg_people, gg_film,oscars!

# %%
head(genres_experiments)
# Out:
#   tconst    titleType primaryTitle           isAdult startYear runtimeMinutes
# 1 tt0000001 short     Carmencita             0       1894       1
# 2 tt0000002 short     Le clown et ses chiens 0       1892       5
# 3 tt0000003 short     Pauvre Pierrot         0       1892       4
# 4 tt0000004 short     Un bon bock            0       1892      12
# 5 tt0000005 short     Blacksmith Scene       0       1893       1
# 6 tt0000006 short     Chinese Opium Den      0       1894       1
#   genre1      genre2 genre3  category_emmy win_emmy year_cerimony_gg.x
# 1 Documentary Short  0       NA            NA       NA
# 2 Animation   Short  0       NA            NA       NA
# 3 Animation   Comedy Romance NA            NA       NA
# 4 Animation   Short  0       NA            NA       NA
# 5 Comedy      Short  0       NA            NA       NA
# 6 Short       0      0       NA            NA       NA
#   category_gg_film win_gg_film year_cerimony_gg.y category_gg_people nominee
# 1 NA               NA          NA                 NA                 NA
# 2 NA               NA          NA                 NA                 NA
# 3 NA               NA          NA                 NA                 NA
# 4 NA               NA          NA                 NA                 NA
# 5 NA               NA          NA                 NA                 NA
# 6 NA               NA          NA                 NA                 NA
#   win_gg_people year_cerimony_oscars category_oscars name win_oscars
# 1 NA            NA                   NA              NA   NA
# 2 NA            NA                   NA              NA   NA
# 3 NA            NA                   NA              NA   NA
# 4 NA            NA                   NA              NA   NA
# 5 NA            NA                   NA              NA   NA
# 6 NA            NA                   NA              NA   NA
#   averageRating numVotes
# 1 5.6           1654
# 2 6.1            199
# 3 6.5           1366
# 4 6.2            121
# 5 6.2           2149
# 6 5.3            115

# %%
genres_winnings_emmys = genres_experiments[which(genres_experiments$win_emmy == 1),]
genres_winnings_gg_people = genres_experiments[which(genres_experiments$win_gg_people == 1),]
genres_winnings_gg_film = genres_experiments[which(genres_experiments$win_gg_film == 1),]
genres_winnings_oscars= genres_experiments[which(genres_experiments$win_oscars== 1),]

# %%
copy_genres_winnings = genres_winnings_emmys
all_gender_winnings_columns = copy_genres_winnings %>% select(genre1,genre2,genre3)
first_gender_counts = all_gender_winnings_columns %>% count(genre1)
colnames(first_gender_counts) = c("genre","first_genre")
second_gender_counts = all_gender_winnings_columns %>% count(genre2)
colnames(second_gender_counts) = c("genre","second_genre")
third_gender_counts = all_gender_winnings_columns %>% count(genre3)
colnames(third_gender_counts) = c("genre","third_genre")
first_second_gender_counts = full_join(first_gender_counts,second_gender_counts,by="genre")
first_second_third_gender_counts = full_join(first_second_gender_counts,third_gender_counts,by="genre")
first_second_third_gender_counts[is.na(first_second_third_gender_counts)] <- 0
total = first_second_third_gender_counts %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
first_second_third_gender_counts$total = total
first_second_third_gender_counts = first_second_third_gender_counts[first_second_third_gender_counts$genre!=0,]
label_genre = first_second_third_gender_counts
label_genre = arrange(label_genre,total)
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)
emmys_genres_wins = ggplot()+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre+third_genre,fill="Third Gender"),stat="identity")+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre,fill="Second Genre"), stat="identity") +
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre,fill="First Genre"),stat="identity") +
scale_fill_manual(values=c("#1e3d59","#f5f0e1","#ff6e40"))+
ylim(-100,700)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.8, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(first_second_third_gender_counts)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=650, label="Genres per Emmy winning awards"), color="black", inherit.aes = FALSE)

# %%
emmys_genres_wins
# Out:
# plot without title

# %%
ggsave(plot=emmys_genres_wins,file="genres_per_emmy_winning_awards.png",width=7,height=10,dpi=300)

# %%
copy_genres_winnings = genres_winnings_gg_people
all_gender_winnings_columns = copy_genres_winnings %>% select(genre1,genre2,genre3)
first_gender_counts = all_gender_winnings_columns %>% count(genre1)
colnames(first_gender_counts) = c("genre","first_genre")
second_gender_counts = all_gender_winnings_columns %>% count(genre2)
colnames(second_gender_counts) = c("genre","second_genre")
third_gender_counts = all_gender_winnings_columns %>% count(genre3)
colnames(third_gender_counts) = c("genre","third_genre")
first_second_gender_counts = full_join(first_gender_counts,second_gender_counts,by="genre")
first_second_third_gender_counts = full_join(first_second_gender_counts,third_gender_counts,by="genre")
first_second_third_gender_counts[is.na(first_second_third_gender_counts)] <- 0
total = first_second_third_gender_counts %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
first_second_third_gender_counts$total = total
first_second_third_gender_counts = first_second_third_gender_counts[first_second_third_gender_counts$genre!=0,]
label_genre = first_second_third_gender_counts
label_genre = arrange(label_genre,total)
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)
gg_people_genres_wins = ggplot()+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre+third_genre,fill="Third Gender"),stat="identity")+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre,fill="Second Genre"), stat="identity") +
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre,fill="First Genre"),stat="identity") +
scale_fill_manual(values=c("#1e3d59","#f5f0e1","#ff6e40"))+
ylim(-600,5000)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.8, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(first_second_third_gender_counts)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=5000, label="Genres per Golden Globes - people - winning awards"), color="black", inherit.aes = FALSE)

# %%
gg_people_genres_wins
# Out:
# plot without title

# %%
ggsave(plot=gg_people_genres_wins,file="genres_per_ggpeople_winning_awards.png",width=7,height=10,dpi=300)

# %%
copy_genres_winnings = genres_winnings_gg_film
all_gender_winnings_columns = copy_genres_winnings %>% select(genre1,genre2,genre3)
first_gender_counts = all_gender_winnings_columns %>% count(genre1)
colnames(first_gender_counts) = c("genre","first_genre")
second_gender_counts = all_gender_winnings_columns %>% count(genre2)
colnames(second_gender_counts) = c("genre","second_genre")
third_gender_counts = all_gender_winnings_columns %>% count(genre3)
colnames(third_gender_counts) = c("genre","third_genre")
first_second_gender_counts = full_join(first_gender_counts,second_gender_counts,by="genre")
first_second_third_gender_counts = full_join(first_second_gender_counts,third_gender_counts,by="genre")
first_second_third_gender_counts[is.na(first_second_third_gender_counts)] <- 0
total = first_second_third_gender_counts %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
first_second_third_gender_counts$total = total
first_second_third_gender_counts = first_second_third_gender_counts[first_second_third_gender_counts$genre!=0,]
label_genre = first_second_third_gender_counts
label_genre = arrange(label_genre,total)
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)
gg_film_genres_wins = ggplot()+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre+third_genre,fill="Third Gender"),stat="identity")+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre,fill="Second Genre"), stat="identity") +
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre,fill="First Genre"),stat="identity") +
scale_fill_manual(values=c("#1e3d59","#f5f0e1","#ff6e40"))+
ylim(-600,5000)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.8, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(first_second_third_gender_counts)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=5000, label="Genres per Golden Globes - film - winning awards"), color="black", inherit.aes = FALSE)

# %%
gg_film_genres_wins
# Out:
# plot without title

# %%
ggsave(plot=gg_film_genres_wins,file="genres_per_ggfilm_winning_awards.png",width=7,height=10,dpi=300)

# %%
copy_genres_winnings = genres_winnings_oscars
all_gender_winnings_columns = copy_genres_winnings %>% select(genre1,genre2,genre3)
first_gender_counts = all_gender_winnings_columns %>% count(genre1)
colnames(first_gender_counts) = c("genre","first_genre")
second_gender_counts = all_gender_winnings_columns %>% count(genre2)
colnames(second_gender_counts) = c("genre","second_genre")
third_gender_counts = all_gender_winnings_columns %>% count(genre3)
colnames(third_gender_counts) = c("genre","third_genre")
first_second_gender_counts = full_join(first_gender_counts,second_gender_counts,by="genre")
first_second_third_gender_counts = full_join(first_second_gender_counts,third_gender_counts,by="genre")
first_second_third_gender_counts[is.na(first_second_third_gender_counts)] <- 0
total = first_second_third_gender_counts %>% select(2,3,4)
total = rowSums(total,na.rm=TRUE)
first_second_third_gender_counts$total = total
first_second_third_gender_counts = first_second_third_gender_counts[first_second_third_gender_counts$genre!=0,]
label_genre = first_second_third_gender_counts
label_genre = arrange(label_genre,total)
label_genre$id = seq(1,nrow(label_genre))
label_genre$labels = paste("  ",label_genre$genre," ",label_genre$total,"  ")
nbars = nrow(label_genre)
angle = 90 - 360 * (label_genre$id) / nbars
label_genre$hjust<-ifelse(angle < -90, 1, 0)
label_genre$angle<-ifelse(angle < -90, angle+180, angle)
gg_film_genres_wins = ggplot()+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre+third_genre,fill="Third Gender"),stat="identity")+
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre+second_genre,fill="Second Genre"), stat="identity") +
geom_bar(data = first_second_third_gender_counts, aes(x=reorder(genre,total),y=first_genre,fill="First Genre"),stat="identity") +
scale_fill_manual(values=c("#1e3d59","#f5f0e1","#ff6e40"))+
ylim(-600,5000)+
theme_bw()+
theme(plot.title=element_text(),
    axis.text = element_blank(),
    axis.title = element_blank(),
    panel.grid = element_blank(),
    legend.position = c(0.8, 0.5),
    plot.margin = unit(rep(-2,4), "cm"))+labs(fill = "Legend")+
coord_polar(start = 0)+
geom_text(data=label_genre, aes(x=seq(1,nrow(first_second_third_gender_counts)), y=total+10, label=labels, hjust=hjust), 
                                color="black", size=2.3, angle= label_genre$angle, inherit.aes = FALSE)+
geom_text(aes(x=-1, y=5000, label="Genres per Oscars winning awards"), color="black", inherit.aes = FALSE)

# %%
gg_film_genres_wins
# Out:
# plot without title

# %%
ggsave(plot=gg_film_genres_wins,file="genres_per_oscars_winning_awards.png",width=7,height=10,dpi=300)
