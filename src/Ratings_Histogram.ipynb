# %%
merged=read.delim('/home/brunovaz19/Desktop/Data Science/Masters/Year 1/Semester 1/Visualização de Dados/IMDb_Datasets_Filtered/merge_basics_ratings_crew.tsv')

# %%
library(ggplot2)
library(scales)
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”

# %%
ggplot(merged[merged$averageRating>=1,],aes(x=averageRating))+
geom_histogram(bins=10,color=1,fill=4,alpha=.3)+
scale_x_continuous(breaks=seq(0,10,1))+
labs(x='Average Rating',y='Frequency')
# Out:
# plot without title
