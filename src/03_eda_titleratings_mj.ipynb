# %% [markdown]
# ### Imports

# %%
library(ggplot2)

# %% [markdown]
# ### Read file

# %%
path = "./../dataset/"

# ta <- read.delim(paste(path, "TitleAkas.tsv", sep=""), header=TRUE)
# tb <- read.delim(paste(path, "TitleBasics.tsv", sep=""), header=TRUE)
# tc <- read.delim(paste(path, "TitleCrew.tsv", sep=""), header=TRUE)
tr <- read.delim(paste(path, "TitleRatings.tsv", sep=""), header=TRUE)
# tp <- read.delim(paste(path, "TitlePrincipals.tsv", sep=""), header=TRUE)
# Out:
# Time difference of 1.168208 mins

# %%
head(tr)
# Out:
#   tconst    averageRating numVotes
# 1 tt0000001 5.6           1654
# 2 tt0000002 6.1            199
# 3 tt0000003 6.5           1366
# 4 tt0000004 6.2            121
# 5 tt0000005 6.2           2149
# 6 tt0000006 5.3            115

# %% [markdown]
# ### Average Rating

# %%
ggplot(tr, aes(x=averageRating)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(tr, aes(y=averageRating)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# weighted average of all the individual user ratings
# * normal distribution, slightly skeewed to the right
# * some outliers

# %% [markdown]
# ### Number of Votes

# %%
ggplot(tr, aes(x=numVotes)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(tr, aes(y=numVotes)) + geom_boxplot()

# %%
summary(tr[,"numVotes"])
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
#       5.0       9.0      20.0     955.8      79.0 2296829.0

# %% [markdown]
# number of votes the title has received
# * normalization of variables
