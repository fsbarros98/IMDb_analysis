# %%
library(ggplot2)
library(plyr)
library(arules)
library(reshape2)
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”
# Loading required package: Matrix
#
#
# Attaching package: ‘arules’
#
#
# The following objects are masked from ‘package:base’:
#
#     abbreviate, write

# %%
options(repr.plot.width=15, repr.plot.height=7, repr.plot.res = 150)

# %%
getwd()
# Out:
# [1] "/home/brunovaz19/Desktop/Data Science/Masters/Year 1/Semester 1/Visualização de Dados/VD_project/src"

# %%
title_akas=read.delim('../../IMDb_Datasets_Filtered/2.Cleaned/cleaned_filtered_title_akas.tsv')
merged=read.delim('../../IMDb_Datasets_Filtered/merge_basics_ratings_crew.tsv')

# %%
head(title_akas)
head(merged)
# Out:
#   titleId   region isOriginalTitle
# 1 tt0000001 UA     0
# 2 tt0000001 DE     0
# 3 tt0000001 HU     0
# 4 tt0000001 GR     0
# 5 tt0000001 RU     0
# 6 tt0000001 US     0
#   tconst    titleType isAdult startYear runtimeMinutes genre1      genre2
# 1 tt0000001 short     0       1894       1             Documentary Short
# 2 tt0000002 short     0       1892       5             Animation   Short
# 3 tt0000003 short     0       1892       4             Animation   Comedy
# 4 tt0000004 short     0       1892      12             Animation   Short
# 5 tt0000005 short     0       1893       1             Comedy      Short
# 6 tt0000006 short     0       1894       1             Short       0
#   genre3  averageRating numVotes n_directors n_writers
# 1 0       5.6           1654     1           1
# 2 0       6.1            199     1           1
# 3 Romance 6.5           1366     1           1
# 4 0       6.2            121     1           1
# 5 0       6.2           2149     1           1
# 6 0       5.3            115     1           1

# %% [markdown]
# # Creating a new dataset

# %%
freq=count(title_akas,'titleId') #Let's joint rows with the same titleId
names(freq)[names(freq) == "titleId"]="tconst" #And change the tiltleId name to tconst to perform a merge
new_merge=merge(freq,merged,by='tconst',all.x=T) #Merging
regions_success=new_merge[c('tconst','freq','averageRating','numVotes')] #Just want to analyze these attributes
regions_success=subset(regions_success,!is.na(averageRating) & averageRating>0,) #Just movies with ratings
regions_success=regions_success[order(regions_success$freq),] #Let's reorder the rows

# %%
tail(regions_success)
# Out:
#        tconst    freq averageRating numVotes
# 74842  tt0087332 72   7.8            349555
# 825369 tt5814534 72   6.8             30967
# 73950  tt0086190 75   8.3            934060
# 75668  tt0088247 76   8.0            789645
# 69244  tt0080684 77   8.7           1139605
# 57292  tt0060196 78   8.8            677351

# %%
movies_40plus_regions=subset(regions_success,freq>=40)

# %%
movies_40plus_regions

# %%
title_akas[is.element(title_akas$titleId,movies_40plus_regions$tconst),]
# Out:
#         titleId   region isOriginalTitle
# 9047    tt0004972 TR     0
# 9048    tt0004972 FI     0
# 9049    tt0004972 US     0
# 9050    tt0004972 JP     0
# 9051    tt0004972 AU     0
# 9052    tt0004972 FR     0
# 9053    tt0004972 BR     0
# 9054    tt0004972 CZ     0
# 9055    tt0004972 FI     0
# 9056    tt0004972 DK     0
# 9057    tt0004972 DE     0
# 9058    tt0004972 RO     0
# 9059    tt0004972 ES     0
# 9060    tt0004972 AR     0
# 9061    tt0004972 LT     0
# 9062    tt0004972 PL     0
# 9063    tt0004972 MX     0
# 9064    tt0004972 GR     0
# 9065    tt0004972 HU     0
# 9066    tt0004972 US     0
# 9067    tt0004972 PT     0
# 9068    tt0004972 TW     0
# 9069    tt0004972 UY     0
# 9070    tt0004972 XWW    0
# 9071    tt0004972 GR     0
# 9072    tt0004972 NO     0
# 9073    tt0004972 RS     0
# 9074    tt0004972 FI     0
# 9075    tt0004972 IN     0
# 9076    tt0004972 JP     0
# ⋮       ⋮         ⋮      ⋮
# 1880464 tt9426210 FI     0
# 1880465 tt9426210 LV     0
# 1880466 tt9426210 PH     0
# 1880467 tt9426210 UA     0
# 1880468 tt9426210 XWW    0
# 1880469 tt9426210 ES     0
# 1880470 tt9426210 HK     0
# 1880471 tt9426210 FR     0
# 1880472 tt9426210 RU     0
# 1880473 tt9426210 HK     0
# 1880474 tt9426210 AT     0
# 1880475 tt9426210 IN     0
# 1880476 tt9426210 ES     0
# 1880477 tt9426210 IN     0
# 1880478 tt9426210 DE     0
# 1880479 tt9426210 ES     0
# 1880480 tt9426210 CA     0
# 1880481 tt9426210 JP     0
# 1880482 tt9426210 AU     0
# 1880483 tt9426210 SG     0
# 1880484 tt9426210 BR     0
# 1880485 tt9426210 PH     0
# 1880486 tt9426210 TH     0
# 1880487 tt9426210 GB     0
# 1880488 tt9426210 KR     0
# 1880489 tt9426210 XWW    0
# 1880490 tt9426210 IE     0
# 1880491 tt9426210 XWW    0
# 1880492 tt9426210 PT     0
# 1880493 tt9426210 MX     0

# %%
ggplot(title_akas[is.element(title_akas$titleId,movies_40plus_regions$tconst),],aes(x=region))+
    geom_bar(stat='count')
# Out:
# plot without title

# %%
movie_freq=c()
for (i in title_akas[is.element(title_akas$titleId,movies_40plus_regions$tconst),]$titleId){
    movie_freq=append(movie_freq,regions_success[regions_success$tconst==i,]$freq)
}

# %%
regions_movies_40_plus=title_akas[is.element(title_akas$titleId,movies_40plus_regions$tconst),]

# %%
regions_movies_40_plus$nregions=movie_freq

# %%
n_movies=c()
regions=c()

for (i in unique(regions_movies_40_plus$region)){
    regions=append(regions,i)
    n_movies=append(n_movies,length(unique(subset(regions_movies_40_plus,region==i)$titleId)))
}

# %%
regions_n_movies=data.frame(regions,n_movies)

# %%
regions_n_movies=regions_n_movies[order(-regions_n_movies$n_movies),]

# %%
g=ggplot(regions_n_movies[1:30,],aes(y=reorder(regions,n_movies),x=n_movies))+
    geom_bar(stat='identity',fill=4,color=1)+
    theme_bw(base_size=16)+
    xlab('Number of Movies')+
    ylab('Regions')+
    scale_x_continuous(breaks=seq(0,1400,100))+
    theme(axis.text.x=element_text(angle=90, hjust=1))

# %%
g
# Out:
# plot without title

# %%
ggsave(plot=g,file="regions_40_plus.png",width=4,height=6,dpi=300)

# %%
subset(regions_movies_40_plus,region=='SE')
# Out:
#         titleId   region isOriginalTitle nregions
# 9079    tt0004972 SE     0               42
# 20651   tt0010323 SE     0               41
# 20660   tt0010323 SE     0               41
# 26217   tt0012349 SE     0               44
# 29469   tt0013442 SE     0               47
# 37124   tt0015648 SE     0               60
# 38002   tt0015864 SE     0               46
# 46535   tt0017925 SE     0               48
# 49013   tt0018455 SE     0               43
# 50676   tt0018773 SE     0               41
# 53065   tt0019254 SE     0               42
# 59978   tt0020530 SE     0               44
# 60539   tt0020629 SE     0               42
# 65892   tt0021749 SE     0               54
# 67632   tt0022100 SE     0               51
# 73807   tt0023312 SE     0               41
# 75004   tt0023551 SE     0               43
# 75024   tt0023551 SE     0               43
# 77236   tt0023969 SE     0               45
# 78351   tt0024184 SE     0               40
# 78597   tt0024216 SE     0               42
# 80745   tt0024601 SE     0               42
# 80764   tt0024601 SE     0               42
# 80773   tt0024601 SE     0               42
# 82147   tt0024852 SE     0               51
# 82154   tt0024852 SE     0               51
# 82187   tt0024852 SE     0               51
# 84619   tt0025316 SE     0               46
# 88276   tt0026029 SE     0               47
# 89194   tt0026174 SE     0               42
# ⋮       ⋮         ⋮      ⋮               ⋮
# 1727853 tt5220122 SE     0               60
# 1727884 tt5220122 SE     0               60
# 1728150 tt5222918 SE     0               40
# 1739531 tt5311514 SE     0               51
# 1749916 tt5431890 SE     0               43
# 1754013 tt5463162 SE     0               56
# 1758748 tt5501104 SE     0               45
# 1761386 tt5523010 SE     0               48
# 1768096 tt5580390 SE     0               50
# 1771553 tt5606664 SE     0               47
# 1775475 tt5639354 SE     0               42
# 1778181 tt5657846 SE     0               43
# 1783545 tt5700672 SE     0               48
# 1785165 tt5715410 SE     0               45
# 1785944 tt5719700 SE     0               41
# 1786443 tt5723272 SE     0               40
# 1786888 tt5726616 SE     0               48
# 1787062 tt5727282 SE     0               41
# 1787067 tt5727282 SE     0               41
# 1790467 tt5758778 SE     0               41
# 1797962 tt5814534 SE     0               72
# 1802662 tt5848272 SE     0               56
# 1835235 tt6105098 SE     0               56
# 1839153 tt6135348 SE     0               40
# 1851966 tt7131622 SE     0               64
# 1853081 tt7139936 SE     0               40
# 1853939 tt7146812 SE     0               50
# 1868193 tt7282468 SE     0               42
# 1868568 tt7286456 SE     0               48
# 1880451 tt9426210 SE     0               47

# %%
length(unique(subset(regions_movies_40_plus,region=='SE')$titleId))
# Out:
# [1] 1017

# %%
regions_movies_40_plus[order(regions_movies_40_plus$nregions),]
# Out:
#        titleId   region isOriginalTitle nregions
# 78351  tt0024184 SE     0               40
# 78352  tt0024184 FI     0               40
# 78353  tt0024184 AU     0               40
# 78354  tt0024184 UA     0               40
# 78355  tt0024184 HU     0               40
# 78356  tt0024184 LT     0               40
# 78357  tt0024184 HR     0               40
# 78358  tt0024184 FR     0               40
# 78359  tt0024184 TR     0               40
# 78360  tt0024184 GR     0               40
# 78361  tt0024184 SK     0               40
# 78362  tt0024184 XYU    0               40
# 78363  tt0024184 UY     0               40
# 78364  tt0024184 IT     0               40
# 78365  tt0024184 CZ     0               40
# 78366  tt0024184 PT     0               40
# 78367  tt0024184 BR     0               40
# 78368  tt0024184 US     0               40
# 78369  tt0024184 SUHH   0               40
# 78370  tt0024184 ES     0               40
# 78371  tt0024184 JP     0               40
# 78372  tt0024184 DE     0               40
# 78373  tt0024184 NO     0               40
# 78374  tt0024184 GR     0               40
# 78375  tt0024184 BG     0               40
# 78376  tt0024184 PL     0               40
# 78377  tt0024184 TW     0               40
# 78378  tt0024184 SI     0               40
# 78379  tt0024184 RS     0               40
# 78380  tt0024184 XYU    0               40
# ⋮      ⋮         ⋮      ⋮               ⋮
# 331278 tt0060196 CO     0               78
# 331279 tt0060196 XEU    0               78
# 331280 tt0060196 CA     0               78
# 331281 tt0060196 HK     0               78
# 331282 tt0060196 FI     0               78
# 331283 tt0060196 XWW    0               78
# 331284 tt0060196 TW     0               78
# 331285 tt0060196 FI     0               78
# 331286 tt0060196 JP     0               78
# 331287 tt0060196 IT     0               78
# 331288 tt0060196 XYU    0               78
# 331289 tt0060196 AR     0               78
# 331290 tt0060196 RO     0               78
# 331291 tt0060196 ES     0               78
# 331292 tt0060196 GB     0               78
# 331293 tt0060196 SI     0               78
# 331294 tt0060196 GR     0               78
# 331295 tt0060196 BG     0               78
# 331296 tt0060196 HR     0               78
# 331297 tt0060196 BR     0               78
# 331298 tt0060196 BE     0               78
# 331299 tt0060196 SK     0               78
# 331300 tt0060196 NL     0               78
# 331301 tt0060196 JP     0               78
# 331302 tt0060196 HU     0               78
# 331303 tt0060196 XYU    0               78
# 331304 tt0060196 SE     0               78
# 331305 tt0060196 HK     0               78
# 331306 tt0060196 FR     0               78
# 331307 tt0060196 CSHH   0               78

# %%
frequencies = unique(regions_success$freq)
means=c()
counts=c()
for (i in frequencies){
    means=append(means,mean(subset(regions_success,freq==i)$averageRating))
    counts=append(counts,nrow(subset(regions_success,freq==i)))
}

# %%
freq_ratings=data.frame(frequencies,means,counts)

# %%
#Discretizing the counts attribute for graphical purposes
freq_ratings$discrete=discretize(freq_ratings$counts, method = "cluster",breaks=20)

# %%
freq_ratings
# Out:
#    frequencies means    counts discrete
# 1   1          6.603996 125618 [8.72e+04,1.26e+05]
# 2   2          6.249573  48803 [3.68e+04,8.72e+04)
# 3   3          6.134586  24741 [1.98e+04,3.68e+04)
# 4   4          6.095849  14863 [1.19e+04,1.98e+04)
# 5   5          6.085821  10163 [6.99e+03,1.19e+04)
# 6   6          6.038636   7581 [6.99e+03,1.19e+04)
# 7   7          6.032116   5670 [4.32e+03,6.99e+03)
# 8   8          6.016122   4559 [4.32e+03,6.99e+03)
# 9   9          6.002685   3836 [2.97e+03,4.32e+03)
# 10 10          5.982750   3200 [2.97e+03,4.32e+03)
# 11 11          6.036821   2705 [1.98e+03,2.97e+03)
# 12 12          6.014760   2412 [1.98e+03,2.97e+03)
# 13 13          6.017467   2124 [1.98e+03,2.97e+03)
# 14 14          6.059967   1801 [1.31e+03,1.98e+03)
# 15 15          6.108559   1624 [1.31e+03,1.98e+03)
# 16 16          6.080529   1438 [1.31e+03,1.98e+03)
# 17 17          6.131394   1341 [1.31e+03,1.98e+03)
# 18 18          6.197390   1226 [898,1.31e+03)
# 19 19          6.234270   1103 [898,1.31e+03)
# 20 20          6.267505    994 [898,1.31e+03)
# 21 21          6.276688    948 [898,1.31e+03)
# 22 22          6.387409    826 [595,898)
# 23 23          6.356511    814 [595,898)
# 24 24          6.435431    731 [595,898)
# 25 25          6.510248    644 [595,898)
# 26 26          6.539075    627 [595,898)
# 27 27          6.552974    538 [380,595)
# 28 28          6.561814    474 [380,595)
# 29 29          6.548589    496 [380,595)
# 30 30          6.564090    401 [380,595)
# ⋮  ⋮           ⋮        ⋮      ⋮
# 47 47          7.147297 74     [66.4,109)
# 48 48          6.983951 81     [66.4,109)
# 49 49          7.365306 49     [40.6,66.4)
# 50 50          7.300000 48     [40.6,66.4)
# 51 51          7.163889 36     [23.4,40.6)
# 52 52          7.424242 33     [23.4,40.6)
# 53 53          7.300000 29     [23.4,40.6)
# 54 54          7.409091 22     [8.42,23.4)
# 55 55          7.372727 11     [8.42,23.4)
# 56 56          7.493333 15     [8.42,23.4)
# 57 57          7.458333 12     [8.42,23.4)
# 58 58          7.575000 12     [8.42,23.4)
# 59 59          7.807692 13     [8.42,23.4)
# 60 60          8.028571 14     [8.42,23.4)
# 61 61          7.471429  7     [1,8.42)
# 62 62          8.114286  7     [1,8.42)
# 63 63          7.620000  5     [1,8.42)
# 64 64          7.533333  3     [1,8.42)
# 65 65          7.500000  3     [1,8.42)
# 66 66          8.000000  1     [1,8.42)
# 67 67          8.033333  3     [1,8.42)
# 68 68          7.600000  1     [1,8.42)
# 69 69          8.200000  2     [1,8.42)
# 70 70          7.300000  2     [1,8.42)
# 71 71          8.133333  3     [1,8.42)
# 72 72          7.300000  2     [1,8.42)
# 73 75          8.300000  1     [1,8.42)
# 74 76          8.000000  1     [1,8.42)
# 75 77          8.700000  1     [1,8.42)
# 76 78          8.800000  1     [1,8.42)

# %% [markdown]
# # Making some plots

# %%
g = ggplot(freq_ratings,aes(x=frequencies,means))+
    stat_smooth(method=lm,se=F,col='red',size=.2)+
    geom_point(shape=21,aes(size=counts),fill=4,alpha=.5)+#,show.legend=FALSE)+
    guides(colour=guide_colourbar(order=1))+
    scale_size_area(breaks=c(10,100,1000,10000,30000,40000,120000))+
    #scale_fill_continuous(name='Counts',labels=c(expression('1*10'^'5'),'','4','5','6'))+
    #scale_fill_gradientn(name="Counts")+
    xlab('Number of Regions')+
    ylab('Mean Average Ratings')+
    #geom_text(aes(label=paste(counts)),size=2)+
    theme_bw(base_size=10)+
    scale_y_continuous(breaks=seq(5.5,9,.5),limits=c(5.5,9))+
    scale_x_continuous(breaks=seq(0,80,10))+
    theme(legend.position = "bottom")+ 
    annotate("text",x=10,y=8.75,size=5,color='red',label="Correlation = 0.94")+
    labs(size = "Counts")

# %%
g
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggsave(plot=g,file="freqs_ratings_regions.png",width=7,height=3,dpi=300)
# Out:
# `geom_smooth()` using formula 'y ~ x'

# %%
# Very high correlation!
cor(freq_ratings$frequencies,freq_ratings$means,method='pearson')
# Out:
# [1] 0.941574

# %% [markdown]
# ### In the previous scatter plot we can't really se what's happenning in the interval [1,39] in the x-axis. Let's zoom in

# %%
g = ggplot(freq_ratings[1:39,],aes(x=frequencies,means))+
    stat_smooth(method=lm,se=F,col='red',size=.2)+
    geom_point(shape=21,size=10,aes(fill=-log(counts)),alpha=.3,show.legend=FALSE)+
    guides(colour=guide_colourbar(order=1))+
    #scale_fill_continuous(name='Counts',labels=c(expression('1*10'^'5'),'','4','5','6'))+
    #scale_fill_gradientn(name="Counts")+
    xlab('Number of Regions')+
    ylab('Mean Average Ratings')+
    geom_text(aes(label=paste(counts)),size=3)+
    theme_bw(base_size=19)+
    scale_y_continuous(breaks=seq(5.5,7,.5),limits=c(5.5,7))+
    scale_x_continuous(breaks=seq(0,80,10))+
    theme(legend.position = "bottom")

# %%
g
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggsave(plot=g,file="freqs_ratings_regions_zoom.png",width=15,height=8,dpi=300)
# Out:
# `geom_smooth()` using formula 'y ~ x'

# %% [markdown]
# # Let's see some common characteristics of the movies which were translated to a certain number of region and the respetive mean average rating for that number of regions is 7 or above

# %%
f=subset(freq_ratings,means>=7)$frequencies

# %%
t=subset(new_merge,freq %in% f)

# %%
t[is.na(t$averageRating),] #It's just a movie, so let's remove it
t=t[!is.na(t$averageRating),]
# Out:
#       tconst    freq titleType isAdult startYear runtimeMinutes genre1 genre2
# 65115 tt0074084 43   NA        NA      NA        NA             NA     NA
#       genre3 averageRating numVotes n_directors n_writers
# 65115 NA     NA            NA       NA          NA

# %%
head(t)
# Out:
#       tconst    freq titleType isAdult startYear runtimeMinutes genre1  genre2
# 13245 tt0013442 47   movie     0       1922       94            Fantasy Horror
# 15412 tt0015648 60   movie     0       1925       75            Drama   History
# 18189 tt0018455 43   movie     0       1927       94            Drama   Romance
# 21405 tt0021749 54   movie     0       1931       87            Comedy  Drama
# 21746 tt0022100 51   movie     0       1931      117            Crime   Mystery
# 22535 tt0022913 43   movie     0       1932       64            Drama   Horror
#       genre3   averageRating numVotes n_directors n_writers
# 13245 0        7.9            87420   1           2
# 15412 Thriller 8.0            52196   1           5
# 18189 0        8.1            46354   1           4
# 21405 Romance  8.5           164387   1           3
# 21746 Thriller 8.3           140732   1           3
# 22535 0        7.9            41495   1           6

# %%
ggplot(t,aes(x=averageRating))+
    geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Only 6 movies with ratings less than 5

# %% [markdown]
# # Let's see the genres - just genre1 and genre2

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.4     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()   masks plyr::arrange()
# ✖ purrr::compact()   masks plyr::compact()
# ✖ dplyr::count()     masks plyr::count()
# ✖ tidyr::expand()    masks Matrix::expand()
# ✖ dplyr::failwith()  masks plyr::failwith()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::id()        masks plyr::id()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::mutate()    masks plyr::mutate()
# ✖ tidyr::pack()      masks Matrix::pack()
# ✖ dplyr::recode()    masks arules::recode()
# ✖ dplyr::rename()    masks plyr::rename()
# ✖ dplyr::summarise() masks plyr::summarise()
# ✖ dplyr::summarize() masks plyr::summarize()
# ✖ tidyr::unpack()    masks Matrix::unpack()

# %%
genres=t[,c(7,8)] #Just 2 genres

# %%
genres=table(interaction(genres)) #Creating a table with the interactions between genres
genres=melt(genres, value.name="count") #Converting the table into a dataframe
genres=subset(genres,count>0) #Some combinations of genres have 0 movies, which are useless
genres=separate(genres,'Var1',sep='[.]',into=c('genre1','genre2')) #Separating the Var1 column into 2 columns

# %%
#Professsor's code - Notebook 10
g=ggplot(genres, aes(x=genre1, y=genre2)) +
    geom_point(aes(size=count), shape=21, color="skyblue4", fill="skyblue4") +
    scale_size_area(max_size=10, guide=FALSE) +
    theme_bw(base_size=19)+
    theme(axis.text.x = element_text(angle = 45, hjust=1),
         panel.grid.major.x=element_line(colour='grey70',size=.5,linetype='dotted'),
         panel.grid.major.y=element_line(colour='grey70',size=.5,linetype='dotted'))+
    labs(x='Genre 1',y='Genre 2')

#The size of the circles represents the number of movies

# %%
g
# Out:
# plot without title

# %%
ggsave(plot=g,file="ballon_plot.png",width=6,height=6,dpi=300)

# %%
genres[genres$genre2=='Null',]$genre2='.Null'
# Out:
# Error in `$<-.data.frame`(`*tmp*`, genre2, value = ".Null"): replacement has 1 row, data has 0
# Traceback:
#
# 1. `$<-`(`*tmp*`, genre2, value = ".Null")
# 2. `$<-.data.frame`(`*tmp*`, genre2, value = ".Null")
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %% [markdown]
# # Let's just see the ones with ratings above 7

# %%
t2=subset(t,averageRating>7)
genres2=t2[,c(7,8)] #Just 2 genres
genres2=table(interaction(genres2)) #Creating a table with the interactions between genres
genres2=melt(genres2, value.name="count") #Converting the table into a dataframe
genres2=subset(genres2,count>0) #Some combinations of genres have 0 movies, which are useless
genres2=separate(genres2,'Var1',sep='[.]',into=c('genre1','genre2')) #Separating the Var1 column into 2 columns

# %%
#Professsor's code - Notebook 10
ggplot(genres2, aes(x=genre1, y=genre2)) +
    geom_point(aes(size=count), shape=21, color="black", fill="cornsilk") +
    scale_size_area(max_size=10, guide=FALSE) +
    theme(axis.text.x = element_text(angle = 90))
# Out:
# plot without title

# %% [markdown]
# The bigger circles are still the same: Action,Adventure ; Adventure,Animation; Crime,Drama and (just) Drama

# %% [markdown]
# # Looking at the 3 genres

# %%
three_genres=t[,c(7,8,9)]

# %%
three_genres=table(interaction(three_genres)) #Creating a table with the interactions between genres
three_genres=melt(three_genres, value.name="count") #Converting the table into a dataframe
three_genres=subset(three_genres,count>0) #Some combinations of genres have 0 movies, which are useless
three_genres=separate(three_genres,'Var1',sep='[.]',into=c('genre1','genre2','genre3')) #Separating the Var1 column into 2 columns

# %%
head(three_genres)
# Out:
#    genre1   genre2    genre3 count
# 5  Comedy   0         0      11
# 7  Drama    0         0      21
# 11 Horror   0         0       5
# 14 Thriller 0         0       1
# 15 Western  0         0       7
# 16 Action   Adventure 0       7

# %%
three_genres=three_genres[order(three_genres$count,decreasing=TRUE),]

# %%
head(three_genres)
#Favorite 3 genres combinations
# Out:
#      genre1    genre2    genre3   count
# 632  Adventure Animation Comedy   40
# 4216 Action    Adventure Sci-Fi   28
# 7    Drama     0         0        21
# 4816 Action    Adventure Thriller 16
# 1216 Action    Adventure Drama    15
# 1816 Action    Adventure Fantasy  14

# %% [markdown]
# # Looking at the titleType

# %%
t[t$titleType=='tvMovie',] #1 in this category
t[t$titleType=='short',] #0 in this category
#From the 535 row of the t dataset, 534 are movies
# Out:
#       tconst    freq titleType isAdult startYear runtimeMinutes genre1
# 68541 tt0079802 50   tvMovie   0       1980      98             Action
#       genre2    genre3    averageRating numVotes n_directors n_writers
# 68541 Adventure Animation 5.7           3598     2           2
#      tconst freq titleType isAdult startYear runtimeMinutes genre1 genre2
#      genre3 averageRating numVotes n_directors n_writers
# [1] 535

# %% [markdown]
# # isAdult

# %%
t[t$isAdult==1,]
#All of them are non-adult movies
# Out:
#      tconst freq titleType isAdult startYear runtimeMinutes genre1 genre2
#      genre3 averageRating numVotes n_directors n_writers

# %% [markdown]
# # Runtime Minutes

# %%
ggplot(t,aes(x=runtimeMinutes))+
    geom_histogram(bins=12,fill=4,col=1)+
    stat_bin(bins=12,geom="text", aes(label=..count..), vjust=-1) +
    scale_x_continuous(breaks=seq(50,240,10))
# Out:
# plot without title

# %% [markdown]
# # StartYear

# %%
startYear_freq = t %>% count(startYear)

# %%
head(startYear_freq)
# Out:
#   startYear n
# 1 1922      1
# 2 1925      1
# 3 1927      1
# 4 1931      2
# 5 1932      2
# 6 1934      1

# %%
ggplot(startYear_freq,aes(y=n,x=startYear))+
    geom_line(size=1.5,col=9)+
    geom_point(shape=21,size=4,fill=4,col=4)+
    scale_x_continuous(breaks=seq(1925,2020,5))
# Out:
# plot without title
